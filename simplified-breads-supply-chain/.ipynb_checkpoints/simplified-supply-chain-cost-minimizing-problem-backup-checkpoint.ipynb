# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

import pulp

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %% [markdown]
# ## Read Data.

# %%
df_demand_superA = pd.read_csv('dataset/demand_superA.csv')
df_demand_superB = pd.read_csv('dataset/demand_superB.csv')
df_demand_superC = pd.read_csv('dataset/demand_superC.csv')

df_demand_superA['super'] = 'superA'
df_demand_superB['super'] = 'superB'
df_demand_superC['super'] = 'superC'

df_demand = pd.concat([df_demand_superA, df_demand_superB, df_demand_superC])

df_demand.set_index(keys=['month', 'super'], inplace=True)
df_demand
# Out:
#               breadA  breadB
# month super
# 1     superA     700     620
# 2     superA     780     700
# 3     superA     730     600
# 4     superA     710     680
# 5     superA     670     790
# 6     superA     680     660
# 7     superA     690     780
# 8     superA     750     710
# 9     superA     710     700
# 10    superA     660     690
# 11    superA     770     690
# 12    superA     680     760
# 1     superB     710     770
# 2     superB     730     670
# 3     superB     680     650
# 4     superB     680     740
# 5     superB     700     680
# 6     superB     710     700
# 7     superB     700     790
# 8     superB     790     780
# 9     superB     780     710
# 10    superB     660     710
# 11    superB     750     680
# 12    superB     770     690
# 1     superC     770     680
# 2     superC     760     650
# 3     superC     750     670
# 4     superC     680     680
# 5     superC     680     690
# 6     superC     690     690
# 7     superC     660     710
# 8     superC     700     700
# 9     superC     710     730
# 10    superC     700     700
# 11    superC     700     680
# 12    superC     690     690

# %%
df_cost_factoryA = pd.read_csv('dataset/cost_factoryA.csv')
df_cost_factoryB = pd.read_csv('dataset/cost_factoryB.csv')

# There is no info on January and February for factoryB in dataframe because it starts to operate on March.
# Add the info by ourselves.
dict_add = {'month':[1, 2], 
            'fixed_cost':[0, 0], 
            'breadA_production_cost':[0, 0],
            'breadB_production_cost':[0, 0]}

df_add = pd.DataFrame(dict_add)

df_cost_factoryB = pd.concat([df_cost_factoryB, df_add])

df_cost_factoryA['factory'] = 'factoryA'
df_cost_factoryB['factory'] = 'factoryB'

df_cost = pd.concat([df_cost_factoryA, df_cost_factoryB])

df_cost.set_index(keys=['month', 'factory'], inplace=True)
df_cost
# Out:
#                 fixed_cost  breadA_production_cost  breadB_production_cost
# month factory
# 1     factoryA        5000                     100                     130
# 2     factoryA        5000                      80                     110
# 3     factoryA        5000                      70                     100
# 4     factoryA        5000                     100                     105
# 5     factoryA        5000                     110                     120
# 6     factoryA        5000                      90                     100
# 7     factoryA        5000                     120                     130
# 8     factoryA        5000                     100                     120
# 9     factoryA        5000                      90                     100
# 10    factoryA        5000                      80                     120
# 11    factoryA        5000                      60                     110
# 12    factoryA        5000                      70                     105
# 3     factoryB        6000                     100                     110
# 4     factoryB        6000                     110                     120
# 5     factoryB        6000                     110                     110
# 6     factoryB        6000                     120                     115
# 7     factoryB        6000                     130                     100
# 8     factoryB        6000                     100                     105
# 9     factoryB        6000                     110                     115
# 10    factoryB        6000                     120                     120
# 11    factoryB        6000                     110                     100
# 12    factoryB        6000                     110                     105
# 1     factoryB           0                       0                       0
# 2     factoryB           0                       0                       0

# %%
df_logistic_raw = pd.read_csv('dataset/monthly_logistic_costs.csv')
display(df_logistic_raw)

df_logistic_factoryA = (pd.melt(df_logistic_raw, id_vars =['supermarket'], value_vars =['factoryA'])
                        .rename(columns={'value':'logistic_cost'}))
df_logistic_factoryB = (pd.melt(df_logistic_raw, id_vars =['supermarket'], value_vars =['factoryB'])
                        .rename(columns={'value':'logistic_cost'}))

df_logistic_factoryA['factory'] = 'factoryA'
df_logistic_factoryB['factory'] = 'factoryB'
df_logistic_factoryA.drop('variable', axis=1, inplace=True)
df_logistic_factoryB.drop('variable', axis=1, inplace=True)

df_logistic = pd.concat([df_logistic_factoryA, df_logistic_factoryB])
df_logistic.replace('A', 'superA', inplace=True)
df_logistic.replace('B', 'superB', inplace=True)
df_logistic.replace('C', 'superC', inplace=True)

df_logistic.set_index(keys=['factory', 'supermarket'], inplace=True)
display(df_logistic)
# Out:
#   supermarket  factoryA  factoryB
# 0           A     10000     25000
# 1           B     40000     12000
# 2           C     12000     10000
#                       logistic_cost
# factory  supermarket
# factoryA superA               10000
#          superB               40000
#          superC               12000
# factoryB superA               25000
#          superB               12000
#          superC               10000

# %% [markdown]
# ### Step 1: Instantiate a problem class.

# %%
model = pulp.LpProblem('minimize-cost', pulp.LpMinimize)

# %% [markdown]
# ### Step 2: Model the decision variables.
#
# In this simplified version, there are 3 costs incurred:
#
# 1. Production costs
# 2. Fixed costs
# 3. Logistic costs
#
#
# We’ll need to model:
#
# 1. Production: Production is modelled as an integer variable.
# 2. Status of the factory (on/off): Factory status is modelled as a binary variable. It will have a value of 1 if the factory is on and a value of 0 when the factory is off.
# 3. Logistic between factories and supermarket (on/off): binary variable. It will have a value of 1 if the factory supplies to the supermarket in particular month and 0 when the factory does not supply to the supermarket.
#
# Binary variables are the same as integer variables but constrained to be >= 0 and <=1.

# %%
factory_status = pulp.LpVariable.dicts('factory_status',
                                   ((month, factory) for month, factory in df_cost.index),
                                   lowBound=0, upBound=1,
                                   cat='Integer')

# %%
factory_status
# Out:
# {(1, 'factoryA'): factory_status_(1,_'factoryA'),
#  (2, 'factoryA'): factory_status_(2,_'factoryA'),
#  (3, 'factoryA'): factory_status_(3,_'factoryA'),
#  (4, 'factoryA'): factory_status_(4,_'factoryA'),
#  (5, 'factoryA'): factory_status_(5,_'factoryA'),
#  (6, 'factoryA'): factory_status_(6,_'factoryA'),
#  (7, 'factoryA'): factory_status_(7,_'factoryA'),
#  (8, 'factoryA'): factory_status_(8,_'factoryA'),
#  (9, 'factoryA'): factory_status_(9,_'factoryA'),
#  (10, 'factoryA'): factory_status_(10,_'factoryA'),
#  (11, 'factoryA'): factory_status_(11,_'factoryA'),
#  (12, 'factoryA'): factory_status_(12,_'factoryA'),
#  (3, 'factoryB'): factory_status_(3,_'factoryB'),
#  (4, 'factoryB'): factory_status_(4,_'factoryB'),
#  (5, 'factoryB'): factory_status_(5,_'factoryB'),
#  (6, 'factoryB'): factory_status_(6,_'factoryB'),
#  (7, 'factoryB'): factory_status_(7,_'factoryB'),
#  (8, 'factoryB'): factory_status_(8,_'factoryB'),
#  (9, 'factoryB'): factory_status_(9,_'factoryB'),
#  (10, 'factoryB'): factory_status_(10,_'factoryB'),
#  (11, 'factoryB'): factory_status_(11,_'factoryB'),
#  (12, 'factoryB'): factory_status_(12,_'factoryB'),
#  (1, 'factoryB'): factory_status_(1,_'factoryB'),
#  (2, 'factoryB'): factory_status_(2,_'factoryB')}

# %%
bread_types = ['breadA', 'breadB']
supermarkets = ['superA', 'superB', 'superC']

# %%
production = pulp.LpVariable.dicts('production',
                                   ((month, factory, supermarket, bread) for month, factory in df_cost.index 
                                    for supermarket in supermarkets for bread in bread_types),
                                   lowBound=0,
                                   cat='Integer')

# %%
production
# Out:
# {(1,
#   'factoryA',
#   'superA',
#   'breadA'): production_(1,_'factoryA',_'superA',_'breadA'),
#  (1,
#   'factoryA',
#   'superA',
#   'breadB'): production_(1,_'factoryA',_'superA',_'breadB'),
#  (1,
#   'factoryA',
#   'superB',
#   'breadA'): production_(1,_'factoryA',_'superB',_'breadA'),
#  (1,
#   'factoryA',
#   'superB',
#   'breadB'): production_(1,_'factoryA',_'superB',_'breadB'),
#  (1,
#   'factoryA',
#   'superC',
#   'breadA'): production_(1,_'factoryA',_'superC',_'breadA'),
#  (1,
#   'factoryA',
#   'superC',
#   'breadB'): production_(1,_'factoryA',_'superC',_'breadB'),
#  (2,
#   'factoryA',
#   'superA',
#   'breadA'): production_(2,_'factoryA',_'superA',_'breadA'),
#  (2,
#   'factoryA',
#   'superA',
#   'breadB'): production_(2,_'factoryA',_'superA',_'breadB'),
#  (2,
#   'factoryA',
#   'superB',
#   'breadA'): production_(2,_'factoryA',_'superB',_'breadA'),
#  (2,
#   'factoryA',
#   'superB',
#   'breadB'): production_(2,_'factoryA',_'superB',_'breadB'),
#  (2,
#   'factoryA',
#   'superC',
#   'breadA'): production_(2,_'factoryA',_'superC',_'breadA'),
#  (2,
#   'factoryA',
#   'superC',
#   'breadB'): production_(2,_'factoryA',_'superC',_'breadB'),
#  (3,
#   'factoryA',
#   'superA',
#   'breadA'): production_(3,_'factoryA',_'superA',_'breadA'),
#  (3,
#   'factoryA',
#   'superA',
#   'breadB'): production_(3,_'factoryA',_'superA',_'breadB'),
#  (3,
#   'factoryA',
#   'superB',
#   'breadA'): production_(3,_'factoryA',_'superB',_'breadA'),
#  (3,
#   'factoryA',
#   'superB',
#   'breadB'): production_(3,_'factoryA',_'superB',_'breadB'),
#  (3,
#   'factoryA',
#   'superC',
#   'breadA'): production_(3,_'factoryA',_'superC',_'breadA'),
#  (3,
#   'factoryA',
#   'superC',
#   'breadB'): production_(3,_'factoryA',_'superC',_'breadB'),
#  (4,
#   'factoryA',
#   'superA',
#   'breadA'): production_(4,_'factoryA',_'superA',_'breadA'),
#  (4,
#   'factoryA',
#   'superA',
#   'breadB'): production_(4,_'factoryA',_'superA',_'breadB'),
#  (4,
#   'factoryA',
#   'superB',
#   'breadA'): production_(4,_'factoryA',_'superB',_'breadA'),
#  (4,
#   'factoryA',
#   'superB',
#   'breadB'): production_(4,_'factoryA',_'superB',_'breadB'),
#  (4,
#   'factoryA',
#   'superC',
#   'breadA'): production_(4,_'factoryA',_'superC',_'breadA'),
#  (4,
#   'factoryA',
#   'superC',
#   'breadB'): production_(4,_'factoryA',_'superC',_'breadB'),
#  (5,
#   'factoryA',
#   'superA',
#   'breadA'): production_(5,_'factoryA',_'superA',_'breadA'),
#  (5,
#   'factoryA',
#   'superA',
#   'breadB'): production_(5,_'factoryA',_'superA',_'breadB'),
#  (5,
#   'factoryA',
#   'superB',
#   'breadA'): production_(5,_'factoryA',_'superB',_'breadA'),
#  (5,
#   'factoryA',
#   'superB',
#   'breadB'): production_(5,_'factoryA',_'superB',_'breadB'),
#  (5,
#   'factoryA',
#   'superC',
#   'breadA'): production_(5,_'factoryA',_'superC',_'breadA'),
#  (5,
#   'factoryA',
#   'superC',
#   'breadB'): production_(5,_'factoryA',_'superC',_'breadB'),
#  (6,
#   'factoryA',
#   'superA',
#   'breadA'): production_(6,_'factoryA',_'superA',_'breadA'),
#  (6,
#   'factoryA',
#   'superA',
#   'breadB'): production_(6,_'factoryA',_'superA',_'breadB'),
#  (6,
#   'factoryA',
#   'superB',
#   'breadA'): production_(6,_'factoryA',_'superB',_'breadA'),
#  (6,
#   'factoryA',
#   'superB',
#   'breadB'): production_(6,_'factoryA',_'superB',_'breadB'),
#  (6,
#   'factoryA',
#   'superC',
#   'breadA'): production_(6,_'factoryA',_'superC',_'breadA'),
#  (6,
#   'factoryA',
#   'superC',
#   'breadB'): production_(6,_'factoryA',_'superC',_'breadB'),
#  (7,
#   'factoryA',
#   'superA',
#   'breadA'): production_(7,_'factoryA',_'superA',_'breadA'),
#  (7,
#   'factoryA',
#   'superA',
#   'breadB'): production_(7,_'factoryA',_'superA',_'breadB'),
#  (7,
#   'factoryA',
#   'superB',
#   'breadA'): production_(7,_'factoryA',_'superB',_'breadA'),
#  (7,
#   'factoryA',
#   'superB',
#   'breadB'): production_(7,_'factoryA',_'superB',_'breadB'),
#  (7,
#   'factoryA',
#   'superC',
#   'breadA'): production_(7,_'factoryA',_'superC',_'breadA'),
#  (7,
#   'factoryA',
#   'superC',
#   'breadB'): production_(7,_'factoryA',_'superC',_'breadB'),
#  (8,
#   'factoryA',
#   'superA',
#   'breadA'): production_(8,_'factoryA',_'superA',_'breadA'),
#  (8,
#   'factoryA',
#   'superA',
#   'breadB'): production_(8,_'factoryA',_'superA',_'breadB'),
#  (8,
#   'factoryA',
#   'superB',
#   'breadA'): production_(8,_'factoryA',_'superB',_'breadA'),
#  (8,
#   'factoryA',
#   'superB',
#   'breadB'): production_(8,_'factoryA',_'superB',_'breadB'),
#  (8,
#   'factoryA',
#   'superC',
#   'breadA'): production_(8,_'factoryA',_'superC',_'breadA'),
#  (8,
#   'factoryA',
#   'superC',
#   'breadB'): production_(8,_'factoryA',_'superC',_'breadB'),
#  (9,
#   'factoryA',
#   'superA',
#   'breadA'): production_(9,_'factoryA',_'superA',_'breadA'),
#  (9,
#   'factoryA',
#   'superA',
#   'breadB'): production_(9,_'factoryA',_'superA',_'breadB'),
#  (9,
#   'factoryA',
#   'superB',
#   'breadA'): production_(9,_'factoryA',_'superB',_'breadA'),
#  (9,
#   'factoryA',
#   'superB',
#   'breadB'): production_(9,_'factoryA',_'superB',_'breadB'),
#  (9,
#   'factoryA',
#   'superC',
#   'breadA'): production_(9,_'factoryA',_'superC',_'breadA'),
#  (9,
#   'factoryA',
#   'superC',
#   'breadB'): production_(9,_'factoryA',_'superC',_'breadB'),
#  (10,
#   'factoryA',
#   'superA',
#   'breadA'): production_(10,_'factoryA',_'superA',_'breadA'),
#  (10,
#   'factoryA',
#   'superA',
#   'breadB'): production_(10,_'factoryA',_'superA',_'breadB'),
#  (10,
#   'factoryA',
#   'superB',
#   'breadA'): production_(10,_'factoryA',_'superB',_'breadA'),
#  (10,
#   'factoryA',
#   'superB',
#   'breadB'): production_(10,_'factoryA',_'superB',_'breadB'),
#  (10,
#   'factoryA',
#   'superC',
#   'breadA'): production_(10,_'factoryA',_'superC',_'breadA'),
#  (10,
#   'factoryA',
#   'superC',
#   'breadB'): production_(10,_'factoryA',_'superC',_'breadB'),
#  (11,
#   'factoryA',
#   'superA',
#   'breadA'): production_(11,_'factoryA',_'superA',_'breadA'),
#  (11,
#   'factoryA',
#   'superA',
#   'breadB'): production_(11,_'factoryA',_'superA',_'breadB'),
#  (11,
#   'factoryA',
#   'superB',
#   'breadA'): production_(11,_'factoryA',_'superB',_'breadA'),
#  (11,
#   'factoryA',
#   'superB',
#   'breadB'): production_(11,_'factoryA',_'superB',_'breadB'),
#  (11,
#   'factoryA',
#   'superC',
#   'breadA'): production_(11,_'factoryA',_'superC',_'breadA'),
#  (11,
#   'factoryA',
#   'superC',
#   'breadB'): production_(11,_'factoryA',_'superC',_'breadB'),
#  (12,
#   'factoryA',
#   'superA',
#   'breadA'): production_(12,_'factoryA',_'superA',_'breadA'),
#  (12,
#   'factoryA',
#   'superA',
#   'breadB'): production_(12,_'factoryA',_'superA',_'breadB'),
#  (12,
#   'factoryA',
#   'superB',
#   'breadA'): production_(12,_'factoryA',_'superB',_'breadA'),
#  (12,
#   'factoryA',
#   'superB',
#   'breadB'): production_(12,_'factoryA',_'superB',_'breadB'),
#  (12,
#   'factoryA',
#   'superC',
#   'breadA'): production_(12,_'factoryA',_'superC',_'breadA'),
#  (12,
#   'factoryA',
#   'superC',
#   'breadB'): production_(12,_'factoryA',_'superC',_'breadB'),
#  (3,
#   'factoryB',
#   'superA',
#   'breadA'): production_(3,_'factoryB',_'superA',_'breadA'),
#  (3,
#   'factoryB',
#   'superA',
#   'breadB'): production_(3,_'factoryB',_'superA',_'breadB'),
#  (3,
#   'factoryB',
#   'superB',
#   'breadA'): production_(3,_'factoryB',_'superB',_'breadA'),
#  (3,
#   'factoryB',
#   'superB',
#   'breadB'): production_(3,_'factoryB',_'superB',_'breadB'),
#  (3,
#   'factoryB',
#   'superC',
#   'breadA'): production_(3,_'factoryB',_'superC',_'breadA'),
#  (3,
#   'factoryB',
#   'superC',
#   'breadB'): production_(3,_'factoryB',_'superC',_'breadB'),
#  (4,
#   'factoryB',
#   'superA',
#   'breadA'): production_(4,_'factoryB',_'superA',_'breadA'),
#  (4,
#   'factoryB',
#   'superA',
#   'breadB'): production_(4,_'factoryB',_'superA',_'breadB'),
#  (4,
#   'factoryB',
#   'superB',
#   'breadA'): production_(4,_'factoryB',_'superB',_'breadA'),
#  (4,
#   'factoryB',
#   'superB',
#   'breadB'): production_(4,_'factoryB',_'superB',_'breadB'),
#  (4,
#   'factoryB',
#   'superC',
#   'breadA'): production_(4,_'factoryB',_'superC',_'breadA'),
#  (4,
#   'factoryB',
#   'superC',
#   'breadB'): production_(4,_'factoryB',_'superC',_'breadB'),
#  (5,
#   'factoryB',
#   'superA',
#   'breadA'): production_(5,_'factoryB',_'superA',_'breadA'),
#  (5,
#   'factoryB',
#   'superA',
#   'breadB'): production_(5,_'factoryB',_'superA',_'breadB'),
#  (5,
#   'factoryB',
#   'superB',
#   'breadA'): production_(5,_'factoryB',_'superB',_'breadA'),
#  (5,
#   'factoryB',
#   'superB',
#   'breadB'): production_(5,_'factoryB',_'superB',_'breadB'),
#  (5,
#   'factoryB',
#   'superC',
#   'breadA'): production_(5,_'factoryB',_'superC',_'breadA'),
#  (5,
#   'factoryB',
#   'superC',
#   'breadB'): production_(5,_'factoryB',_'superC',_'breadB'),
#  (6,
#   'factoryB',
#   'superA',
#   'breadA'): production_(6,_'factoryB',_'superA',_'breadA'),
#  (6,
#   'factoryB',
#   'superA',
#   'breadB'): production_(6,_'factoryB',_'superA',_'breadB'),
#  (6,
#   'factoryB',
#   'superB',
#   'breadA'): production_(6,_'factoryB',_'superB',_'breadA'),
#  (6,
#   'factoryB',
#   'superB',
#   'breadB'): production_(6,_'factoryB',_'superB',_'breadB'),
#  (6,
#   'factoryB',
#   'superC',
#   'breadA'): production_(6,_'factoryB',_'superC',_'breadA'),
#  (6,
#   'factoryB',
#   'superC',
#   'breadB'): production_(6,_'factoryB',_'superC',_'breadB'),
#  (7,
#   'factoryB',
#   'superA',
#   'breadA'): production_(7,_'factoryB',_'superA',_'breadA'),
#  (7,
#   'factoryB',
#   'superA',
#   'breadB'): production_(7,_'factoryB',_'superA',_'breadB'),
#  (7,
#   'factoryB',
#   'superB',
#   'breadA'): production_(7,_'factoryB',_'superB',_'breadA'),
#  (7,
#   'factoryB',
#   'superB',
#   'breadB'): production_(7,_'factoryB',_'superB',_'breadB'),
#  (7,
#   'factoryB',
#   'superC',
#   'breadA'): production_(7,_'factoryB',_'superC',_'breadA'),
#  (7,
#   'factoryB',
#   'superC',
#   'breadB'): production_(7,_'factoryB',_'superC',_'breadB'),
#  (8,
#   'factoryB',
#   'superA',
#   'breadA'): production_(8,_'factoryB',_'superA',_'breadA'),
#  (8,
#   'factoryB',
#   'superA',
#   'breadB'): production_(8,_'factoryB',_'superA',_'breadB'),
#  (8,
#   'factoryB',
#   'superB',
#   'breadA'): production_(8,_'factoryB',_'superB',_'breadA'),
#  (8,
#   'factoryB',
#   'superB',
#   'breadB'): production_(8,_'factoryB',_'superB',_'breadB'),
#  (8,
#   'factoryB',
#   'superC',
#   'breadA'): production_(8,_'factoryB',_'superC',_'breadA'),
#  (8,
#   'factoryB',
#   'superC',
#   'breadB'): production_(8,_'factoryB',_'superC',_'breadB'),
#  (9,
#   'factoryB',
#   'superA',
#   'breadA'): production_(9,_'factoryB',_'superA',_'breadA'),
#  (9,
#   'factoryB',
#   'superA',
#   'breadB'): production_(9,_'factoryB',_'superA',_'breadB'),
#  (9,
#   'factoryB',
#   'superB',
#   'breadA'): production_(9,_'factoryB',_'superB',_'breadA'),
#  (9,
#   'factoryB',
#   'superB',
#   'breadB'): production_(9,_'factoryB',_'superB',_'breadB'),
#  (9,
#   'factoryB',
#   'superC',
#   'breadA'): production_(9,_'factoryB',_'superC',_'breadA'),
#  (9,
#   'factoryB',
#   'superC',
#   'breadB'): production_(9,_'factoryB',_'superC',_'breadB'),
#  (10,
#   'factoryB',
#   'superA',
#   'breadA'): production_(10,_'factoryB',_'superA',_'breadA'),
#  (10,
#   'factoryB',
#   'superA',
#   'breadB'): production_(10,_'factoryB',_'superA',_'breadB'),
#  (10,
#   'factoryB',
#   'superB',
#   'breadA'): production_(10,_'factoryB',_'superB',_'breadA'),
#  (10,
#   'factoryB',
#   'superB',
#   'breadB'): production_(10,_'factoryB',_'superB',_'breadB'),
#  (10,
#   'factoryB',
#   'superC',
#   'breadA'): production_(10,_'factoryB',_'superC',_'breadA'),
#  (10,
#   'factoryB',
#   'superC',
#   'breadB'): production_(10,_'factoryB',_'superC',_'breadB'),
#  (11,
#   'factoryB',
#   'superA',
#   'breadA'): production_(11,_'factoryB',_'superA',_'breadA'),
#  (11,
#   'factoryB',
#   'superA',
#   'breadB'): production_(11,_'factoryB',_'superA',_'breadB'),
#  (11,
#   'factoryB',
#   'superB',
#   'breadA'): production_(11,_'factoryB',_'superB',_'breadA'),
#  (11,
#   'factoryB',
#   'superB',
#   'breadB'): production_(11,_'factoryB',_'superB',_'breadB'),
#  (11,
#   'factoryB',
#   'superC',
#   'breadA'): production_(11,_'factoryB',_'superC',_'breadA'),
#  (11,
#   'factoryB',
#   'superC',
#   'breadB'): production_(11,_'factoryB',_'superC',_'breadB'),
#  (12,
#   'factoryB',
#   'superA',
#   'breadA'): production_(12,_'factoryB',_'superA',_'breadA'),
#  (12,
#   'factoryB',
#   'superA',
#   'breadB'): production_(12,_'factoryB',_'superA',_'breadB'),
#  (12,
#   'factoryB',
#   'superB',
#   'breadA'): production_(12,_'factoryB',_'superB',_'breadA'),
#  (12,
#   'factoryB',
#   'superB',
#   'breadB'): production_(12,_'factoryB',_'superB',_'breadB'),
#  (12,
#   'factoryB',
#   'superC',
#   'breadA'): production_(12,_'factoryB',_'superC',_'breadA'),
#  (12,
#   'factoryB',
#   'superC',
#   'breadB'): production_(12,_'factoryB',_'superC',_'breadB'),
#  (1,
#   'factoryB',
#   'superA',
#   'breadA'): production_(1,_'factoryB',_'superA',_'breadA'),
#  (1,
#   'factoryB',
#   'superA',
#   'breadB'): production_(1,_'factoryB',_'superA',_'breadB'),
#  (1,
#   'factoryB',
#   'superB',
#   'breadA'): production_(1,_'factoryB',_'superB',_'breadA'),
#  (1,
#   'factoryB',
#   'superB',
#   'breadB'): production_(1,_'factoryB',_'superB',_'breadB'),
#  (1,
#   'factoryB',
#   'superC',
#   'breadA'): production_(1,_'factoryB',_'superC',_'breadA'),
#  (1,
#   'factoryB',
#   'superC',
#   'breadB'): production_(1,_'factoryB',_'superC',_'breadB'),
#  (2,
#   'factoryB',
#   'superA',
#   'breadA'): production_(2,_'factoryB',_'superA',_'breadA'),
#  (2,
#   'factoryB',
#   'superA',
#   'breadB'): production_(2,_'factoryB',_'superA',_'breadB'),
#  (2,
#   'factoryB',
#   'superB',
#   'breadA'): production_(2,_'factoryB',_'superB',_'breadA'),
#  (2,
#   'factoryB',
#   'superB',
#   'breadB'): production_(2,_'factoryB',_'superB',_'breadB'),
#  (2,
#   'factoryB',
#   'superC',
#   'breadA'): production_(2,_'factoryB',_'superC',_'breadA'),
#  (2,
#   'factoryB',
#   'superC',
#   'breadB'): production_(2,_'factoryB',_'superC',_'breadB')}

# %%
months = range(1,13)

logistic_status = pulp.LpVariable.dicts('logistic_status',
                                        ((month, factory, supermarket) for month in months for factory, supermarket in df_logistic.index),
                                        lowBound=0, upBound=1, cat='Integer')

# %%
logistic_status
# Out:
# {(1, 'factoryA', 'superA'): logistic_status_(1,_'factoryA',_'superA'),
#  (1, 'factoryA', 'superB'): logistic_status_(1,_'factoryA',_'superB'),
#  (1, 'factoryA', 'superC'): logistic_status_(1,_'factoryA',_'superC'),
#  (1, 'factoryB', 'superA'): logistic_status_(1,_'factoryB',_'superA'),
#  (1, 'factoryB', 'superB'): logistic_status_(1,_'factoryB',_'superB'),
#  (1, 'factoryB', 'superC'): logistic_status_(1,_'factoryB',_'superC'),
#  (2, 'factoryA', 'superA'): logistic_status_(2,_'factoryA',_'superA'),
#  (2, 'factoryA', 'superB'): logistic_status_(2,_'factoryA',_'superB'),
#  (2, 'factoryA', 'superC'): logistic_status_(2,_'factoryA',_'superC'),
#  (2, 'factoryB', 'superA'): logistic_status_(2,_'factoryB',_'superA'),
#  (2, 'factoryB', 'superB'): logistic_status_(2,_'factoryB',_'superB'),
#  (2, 'factoryB', 'superC'): logistic_status_(2,_'factoryB',_'superC'),
#  (3, 'factoryA', 'superA'): logistic_status_(3,_'factoryA',_'superA'),
#  (3, 'factoryA', 'superB'): logistic_status_(3,_'factoryA',_'superB'),
#  (3, 'factoryA', 'superC'): logistic_status_(3,_'factoryA',_'superC'),
#  (3, 'factoryB', 'superA'): logistic_status_(3,_'factoryB',_'superA'),
#  (3, 'factoryB', 'superB'): logistic_status_(3,_'factoryB',_'superB'),
#  (3, 'factoryB', 'superC'): logistic_status_(3,_'factoryB',_'superC'),
#  (4, 'factoryA', 'superA'): logistic_status_(4,_'factoryA',_'superA'),
#  (4, 'factoryA', 'superB'): logistic_status_(4,_'factoryA',_'superB'),
#  (4, 'factoryA', 'superC'): logistic_status_(4,_'factoryA',_'superC'),
#  (4, 'factoryB', 'superA'): logistic_status_(4,_'factoryB',_'superA'),
#  (4, 'factoryB', 'superB'): logistic_status_(4,_'factoryB',_'superB'),
#  (4, 'factoryB', 'superC'): logistic_status_(4,_'factoryB',_'superC'),
#  (5, 'factoryA', 'superA'): logistic_status_(5,_'factoryA',_'superA'),
#  (5, 'factoryA', 'superB'): logistic_status_(5,_'factoryA',_'superB'),
#  (5, 'factoryA', 'superC'): logistic_status_(5,_'factoryA',_'superC'),
#  (5, 'factoryB', 'superA'): logistic_status_(5,_'factoryB',_'superA'),
#  (5, 'factoryB', 'superB'): logistic_status_(5,_'factoryB',_'superB'),
#  (5, 'factoryB', 'superC'): logistic_status_(5,_'factoryB',_'superC'),
#  (6, 'factoryA', 'superA'): logistic_status_(6,_'factoryA',_'superA'),
#  (6, 'factoryA', 'superB'): logistic_status_(6,_'factoryA',_'superB'),
#  (6, 'factoryA', 'superC'): logistic_status_(6,_'factoryA',_'superC'),
#  (6, 'factoryB', 'superA'): logistic_status_(6,_'factoryB',_'superA'),
#  (6, 'factoryB', 'superB'): logistic_status_(6,_'factoryB',_'superB'),
#  (6, 'factoryB', 'superC'): logistic_status_(6,_'factoryB',_'superC'),
#  (7, 'factoryA', 'superA'): logistic_status_(7,_'factoryA',_'superA'),
#  (7, 'factoryA', 'superB'): logistic_status_(7,_'factoryA',_'superB'),
#  (7, 'factoryA', 'superC'): logistic_status_(7,_'factoryA',_'superC'),
#  (7, 'factoryB', 'superA'): logistic_status_(7,_'factoryB',_'superA'),
#  (7, 'factoryB', 'superB'): logistic_status_(7,_'factoryB',_'superB'),
#  (7, 'factoryB', 'superC'): logistic_status_(7,_'factoryB',_'superC'),
#  (8, 'factoryA', 'superA'): logistic_status_(8,_'factoryA',_'superA'),
#  (8, 'factoryA', 'superB'): logistic_status_(8,_'factoryA',_'superB'),
#  (8, 'factoryA', 'superC'): logistic_status_(8,_'factoryA',_'superC'),
#  (8, 'factoryB', 'superA'): logistic_status_(8,_'factoryB',_'superA'),
#  (8, 'factoryB', 'superB'): logistic_status_(8,_'factoryB',_'superB'),
#  (8, 'factoryB', 'superC'): logistic_status_(8,_'factoryB',_'superC'),
#  (9, 'factoryA', 'superA'): logistic_status_(9,_'factoryA',_'superA'),
#  (9, 'factoryA', 'superB'): logistic_status_(9,_'factoryA',_'superB'),
#  (9, 'factoryA', 'superC'): logistic_status_(9,_'factoryA',_'superC'),
#  (9, 'factoryB', 'superA'): logistic_status_(9,_'factoryB',_'superA'),
#  (9, 'factoryB', 'superB'): logistic_status_(9,_'factoryB',_'superB'),
#  (9, 'factoryB', 'superC'): logistic_status_(9,_'factoryB',_'superC'),
#  (10, 'factoryA', 'superA'): logistic_status_(10,_'factoryA',_'superA'),
#  (10, 'factoryA', 'superB'): logistic_status_(10,_'factoryA',_'superB'),
#  (10, 'factoryA', 'superC'): logistic_status_(10,_'factoryA',_'superC'),
#  (10, 'factoryB', 'superA'): logistic_status_(10,_'factoryB',_'superA'),
#  (10, 'factoryB', 'superB'): logistic_status_(10,_'factoryB',_'superB'),
#  (10, 'factoryB', 'superC'): logistic_status_(10,_'factoryB',_'superC'),
#  (11, 'factoryA', 'superA'): logistic_status_(11,_'factoryA',_'superA'),
#  (11, 'factoryA', 'superB'): logistic_status_(11,_'factoryA',_'superB'),
#  (11, 'factoryA', 'superC'): logistic_status_(11,_'factoryA',_'superC'),
#  (11, 'factoryB', 'superA'): logistic_status_(11,_'factoryB',_'superA'),
#  (11, 'factoryB', 'superB'): logistic_status_(11,_'factoryB',_'superB'),
#  (11, 'factoryB', 'superC'): logistic_status_(11,_'factoryB',_'superC'),
#  (12, 'factoryA', 'superA'): logistic_status_(12,_'factoryA',_'superA'),
#  (12, 'factoryA', 'superB'): logistic_status_(12,_'factoryA',_'superB'),
#  (12, 'factoryA', 'superC'): logistic_status_(12,_'factoryA',_'superC'),
#  (12, 'factoryB', 'superA'): logistic_status_(12,_'factoryB',_'superA'),
#  (12, 'factoryB', 'superB'): logistic_status_(12,_'factoryB',_'superB'),
#  (12, 'factoryB', 'superC'): logistic_status_(12,_'factoryB',_'superC')}

# %% [markdown]
# ### Step 3: Add objective function.

# %%
model += pulp.lpSum(
    [factory_status[(month, factory)]*df_cost.loc[(month, factory), 'fixed_cost'] for month, factory in df_cost.index]
    +([production[(month, factory, supermarket, bread)]*df_cost.loc[(month, factory), f'{bread}_production_cost'] for month, factory in df_cost.index 
      for supermarket in supermarkets for bread in bread_types])
    +[logistic_status[(month, factory, supermarket)]*df_logistic.loc[(factory, supermarket), 'logistic_cost'] for month in months for factory, supermarket in df_logistic.index]
)

# %% [markdown]
# ### Step 4: Add constraint.
#
# Production in any month must be equal to demand.

# %%
df_demand.head()
# Out:
#               breadA  breadB
# month super
# 1     superA     700     620
# 2     superA     780     700
# 3     superA     730     600
# 4     superA     710     680
# 5     superA     670     790

# %%
# df_demand_reset_index = df_demand.reset_index()

# df_total_demand = df_demand_reset_index[['month', 'breadA', 'breadB']].groupby('month').sum()

# df_total_demand.head()

# %%
# months = []
# supermarkets = []

# for i in range(len(df_demand)):
    
#     months.append(df_demand.index[i][0])
#     supermarkets.append(df_demand.index[i][1])
    
# for month in range(1,13):
        
#     if month in [1, 2]:
#         model += production[(month, 'factoryA')]==df_total_demand.loc[month, 'breadA']

#     else:
#         model += production[(month, 'factoryA')]+production[(month, 'factoryB')]==df_total_demand.loc[month, 'breadA']
            

# for month in range(1,13):
#     for supermarket in supermarkets:
#         for bread in bread_types:
        
#             if month in [1, 2]:
#                 model += production[(month, 'factoryA', supermarket, bread)]==df_demand.loc[(month, supermarket), bread]

#             else:
#                 model += (production[(month, 'factoryA', supermarket, bread)]+
#                           production[(month, 'factoryB', supermarket, bread)]==df_demand.loc[(month, supermarket), bread])
            
for month in range(1,13):
    for supermarket in supermarkets:
        for bread in bread_types:
        
            if month in [1, 2]:
                model += production[(month, 'factoryA', supermarket, bread)]==df_demand.loc[(month, supermarket), bread]

            else:
                model += (production[(month, 'factoryA', supermarket, bread)]+
                          production[(month, 'factoryB', supermarket, bread)]==df_demand.loc[(month, supermarket), bread])

# %%
df_cost.head()
# Out:
#                 fixed_cost  breadA_production_cost  breadB_production_cost
# month factory
# 1     factoryA        5000                     100                     130
# 2     factoryA        5000                      80                     110
# 3     factoryA        5000                      70                     100
# 4     factoryA        5000                     100                     105
# 5     factoryA        5000                     110                     120

# %%
df_demand.head()
# Out:
#               breadA  breadB
# month super
# 1     superA     700     620
# 2     superA     780     700
# 3     superA     730     600
# 4     superA     710     680
# 5     superA     670     790

# %%
df_demand.loc[(3, 'superB')]
# Out:
# breadA    680
# breadB    650
# Name: (3, superB), dtype: int64

# %%
df_demand.index
# Out:
# MultiIndex([( 1, 'superA'),
#             ( 2, 'superA'),
#             ( 3, 'superA'),
#             ( 4, 'superA'),
#             ( 5, 'superA'),
#             ( 6, 'superA'),
#             ( 7, 'superA'),
#             ( 8, 'superA'),
#             ( 9, 'superA'),
#             (10, 'superA'),
#             (11, 'superA'),
#             (12, 'superA'),
#             ( 1, 'superB'),
#             ( 2, 'superB'),
#             ( 3, 'superB'),
#             ( 4, 'superB'),
#             ( 5, 'superB'),
#             ( 6, 'superB'),
#             ( 7, 'superB'),
#             ( 8, 'superB'),
#             ( 9, 'superB'),
#             (10, 'superB'),
#             (11, 'superB'),
#             (12, 'superB'),
#             ( 1, 'superC'),
#             ( 2, 'superC'),
#             ( 3, 'superC'),
#             ( 4, 'superC'),
#             ( 5, 'superC'),
#             ( 6, 'superC'),
#             ( 7, 'superC'),
#             ( 8, 'superC'),
#             ( 9, 'superC'),
#             (10, 'superC'),
#             (11, 'superC'),
#             (12, 'superC')],
#            names=['month', 'super'])

# %%
factories = ['factoryA', 'factoryB']

for factory in factories:
    for month, supermarket in df_demand.index:
        for bread in bread_types:

            bread_demand = df_demand.loc[(month, supermarket), bread]

            model += (production[(month, factory, supermarket, bread)] == 
                      bread_demand * logistic_status[(month, factory, supermarket)])

#             model += (production[(month, factory, supermarket, bread)] == 
#                               bread_demand * factory_status[(month, factory)])

# %%
# factories = ['factoryA', 'factoryB']

# for factory in factories:
#     for month, supermarket in df_demand.index:
#         for bread in bread_types:

#             bread_demand = df_demand.loc[(month, supermarket), bread]

#             model += (production[(month, factory, supermarket, bread)] == 
#                       bread_demand * logistic_status[(month, factory, supermarket)])

#             model += (production[(month, factory, supermarket, bread)] == 
#                               bread_demand * factory_status[(month, factory)])

# %%
# Factory B starts only from March
model += factory_status[1, 'factoryB'] == 0
model += factory_status[2, 'factoryB'] == 0

model += logistic_status[1, 'factoryB', 'superA'] == 0
model += logistic_status[1, 'factoryB', 'superB'] == 0
model += logistic_status[1, 'factoryB', 'superC'] == 0

model += logistic_status[2, 'factoryB', 'superA'] == 0
model += logistic_status[2, 'factoryB', 'superB'] == 0
model += logistic_status[2, 'factoryB', 'superC'] == 0

# %%
months = range(1,13)

for month in months:

    model += factory_status[month, 'factoryA']+factory_status[month, 'factoryB']>=1

# %%
# months = range(1,13)
# supermarkets = ['superA', 'superB', 'superC']

# for month in months:
#     for supermarket in supermarkets:

#         model += logistic_status[month, 'factoryA', supermarket]+logistic_status[month, 'factoryB', supermarket]==1

# %%
model
# Out:
# minimize-cost:
# MINIMIZE
# 5000*factory_status_(1,_'factoryA') + 5000*factory_status_(10,_'factoryA') + 6000*factory_status_(10,_'factoryB') + 5000*factory_status_(11,_'factoryA') + 6000*factory_status_(11,_'factoryB') + 5000*factory_status_(12,_'factoryA') + 6000*factory_status_(12,_'factoryB') + 5000*factory_status_(2,_'factoryA') + 5000*factory_status_(3,_'factoryA') + 6000*factory_status_(3,_'factoryB') + 5000*factory_status_(4,_'factoryA') + 6000*factory_status_(4,_'factoryB') + 5000*factory_status_(5,_'factoryA') + 6000*factory_status_(5,_'factoryB') + 5000*factory_status_(6,_'factoryA') + 6000*factory_status_(6,_'factoryB') + 5000*factory_status_(7,_'factoryA') + 6000*factory_status_(7,_'factoryB') + 5000*factory_status_(8,_'factoryA') + 6000*factory_status_(8,_'factoryB') + 5000*factory_status_(9,_'factoryA') + 6000*factory_status_(9,_'factoryB') + 10000*logistic_status_(1,_'factoryA',_'superA') + 40000*logistic_status_(1,_'factoryA',_'superB') + 12000*logistic_status_(1,_'factoryA',_'superC') + 25000*logistic_status_(1,_'factoryB',_'superA') + 12000*logistic_status_(1,_'factoryB',_'superB') + 10000*logistic_status_(1,_'factoryB',_'superC') + 10000*logistic_status_(10,_'factoryA',_'superA') + 40000*logistic_status_(10,_'factoryA',_'superB') + 12000*logistic_status_(10,_'factoryA',_'superC') + 25000*logistic_status_(10,_'factoryB',_'superA') + 12000*logistic_status_(10,_'factoryB',_'superB') + 10000*logistic_status_(10,_'factoryB',_'superC') + 10000*logistic_status_(11,_'factoryA',_'superA') + 40000*logistic_status_(11,_'factoryA',_'superB') + 12000*logistic_status_(11,_'factoryA',_'superC') + 25000*logistic_status_(11,_'factoryB',_'superA') + 12000*logistic_status_(11,_'factoryB',_'superB') + 10000*logistic_status_(11,_'factoryB',_'superC') + 10000*logistic_status_(12,_'factoryA',_'superA') + 40000*logistic_status_(12,_'factoryA',_'superB') + 12000*logistic_status_(12,_'factoryA',_'superC') + 25000*logistic_status_(12,_'factoryB',_'superA') + 12000*logistic_status_(12,_'factoryB',_'superB') + 10000*logistic_status_(12,_'factoryB',_'superC') + 10000*logistic_status_(2,_'factoryA',_'superA') + 40000*logistic_status_(2,_'factoryA',_'superB') + 12000*logistic_status_(2,_'factoryA',_'superC') + 25000*logistic_status_(2,_'factoryB',_'superA') + 12000*logistic_status_(2,_'factoryB',_'superB') + 10000*logistic_status_(2,_'factoryB',_'superC') + 10000*logistic_status_(3,_'factoryA',_'superA') + 40000*logistic_status_(3,_'factoryA',_'superB') + 12000*logistic_status_(3,_'factoryA',_'superC') + 25000*logistic_status_(3,_'factoryB',_'superA') + 12000*logistic_status_(3,_'factoryB',_'superB') + 10000*logistic_status_(3,_'factoryB',_'superC') + 10000*logistic_status_(4,_'factoryA',_'superA') + 40000*logistic_status_(4,_'factoryA',_'superB') + 12000*logistic_status_(4,_'factoryA',_'superC') + 25000*logistic_status_(4,_'factoryB',_'superA') + 12000*logistic_status_(4,_'factoryB',_'superB') + 10000*logistic_status_(4,_'factoryB',_'superC') + 10000*logistic_status_(5,_'factoryA',_'superA') + 40000*logistic_status_(5,_'factoryA',_'superB') + 12000*logistic_status_(5,_'factoryA',_'superC') + 25000*logistic_status_(5,_'factoryB',_'superA') + 12000*logistic_status_(5,_'factoryB',_'superB') + 10000*logistic_status_(5,_'factoryB',_'superC') + 10000*logistic_status_(6,_'factoryA',_'superA') + 40000*logistic_status_(6,_'factoryA',_'superB') + 12000*logistic_status_(6,_'factoryA',_'superC') + 25000*logistic_status_(6,_'factoryB',_'superA') + 12000*logistic_status_(6,_'factoryB',_'superB') + 10000*logistic_status_(6,_'factoryB',_'superC') + 10000*logistic_status_(7,_'factoryA',_'superA') + 40000*logistic_status_(7,_'factoryA',_'superB') + 12000*logistic_status_(7,_'factoryA',_'superC') + 25000*logistic_status_(7,_'factoryB',_'superA') + 12000*logistic_status_(7,_'factoryB',_'superB') + 10000*logistic_status_(7,_'factoryB',_'superC') + 10000*logistic_status_(8,_'factoryA',_'superA') + 40000*logistic_status_(8,_'factoryA',_'superB') + 12000*logistic_status_(8,_'factoryA',_'s ...
# SUBJECT TO
# _C1: production_(1,_'factoryA',_'superA',_'breadA') = 700
#
# _C2: production_(1,_'factoryA',_'superA',_'breadB') = 620
#
# _C3: production_(1,_'factoryA',_'superB',_'breadA') = 710
#
# _C4: production_(1,_'factoryA',_'superB',_'breadB') = 770
#
# _C5: production_(1,_'factoryA',_'superC',_'breadA') = 770
#
# _C6: production_(1,_'factoryA',_'superC',_'breadB') = 680
#
# _C7: production_(2,_'factoryA',_'superA',_'breadA') = 780
#
# _C8: production_(2,_'factoryA',_'superA',_'breadB') = 700
#
# _C9: production_(2,_'factoryA',_'superB',_'breadA') = 730
#
# _C10: production_(2,_'factoryA',_'superB',_'breadB') = 670
#
# _C11: production_(2,_'factoryA',_'superC',_'breadA') = 760
#
# _C12: production_(2,_'factoryA',_'superC',_'breadB') = 650
#
# _C13: production_(3,_'factoryA',_'superA',_'breadA')
#  + production_(3,_'factoryB',_'superA',_'breadA') = 730
#
# _C14: production_(3,_'factoryA',_'superA',_'breadB')
#  + production_(3,_'factoryB',_'superA',_'breadB') = 600
#
# _C15: production_(3,_'factoryA',_'superB',_'breadA')
#  + production_(3,_'factoryB',_'superB',_'breadA') = 680
#
# _C16: production_(3,_'factoryA',_'superB',_'breadB')
#  + production_(3,_'factoryB',_'superB',_'breadB') = 650
#
# _C17: production_(3,_'factoryA',_'superC',_'breadA')
#  + production_(3,_'factoryB',_'superC',_'breadA') = 750
#
# _C18: production_(3,_'factoryA',_'superC',_'breadB')
#  + production_(3,_'factoryB',_'superC',_'breadB') = 670
#
# _C19: production_(4,_'factoryA',_'superA',_'breadA')
#  + production_(4,_'factoryB',_'superA',_'breadA') = 710
#
# _C20: production_(4,_'factoryA',_'superA',_'breadB')
#  + production_(4,_'factoryB',_'superA',_'breadB') = 680
#
# _C21: production_(4,_'factoryA',_'superB',_'breadA')
#  + production_(4,_'factoryB',_'superB',_'breadA') = 680
#
# _C22: production_(4,_'factoryA',_'superB',_'breadB')
#  + production_(4,_'factoryB',_'superB',_'breadB') = 740
#
# _C23: production_(4,_'factoryA',_'superC',_'breadA')
#  + production_(4,_'factoryB',_'superC',_'breadA') = 680
#
# _C24: production_(4,_'factoryA',_'superC',_'breadB')
#  + production_(4,_'factoryB',_'superC',_'breadB') = 680
#
# _C25: production_(5,_'factoryA',_'superA',_'breadA')
#  + production_(5,_'factoryB',_'superA',_'breadA') = 670
#
# _C26: production_(5,_'factoryA',_'superA',_'breadB')
#  + production_(5,_'factoryB',_'superA',_'breadB') = 790
#
# _C27: production_(5,_'factoryA',_'superB',_'breadA')
#  + production_(5,_'factoryB',_'superB',_'breadA') = 700
#
# _C28: production_(5,_'factoryA',_'superB',_'breadB')
#  + production_(5,_'factoryB',_'superB',_'breadB') = 680
#
# _C29: production_(5,_'factoryA',_'superC',_'breadA')
#  + production_(5,_'factoryB',_'superC',_'breadA') = 680
#
# _C30: production_(5,_'factoryA',_'superC',_'breadB')
#  + production_(5,_'factoryB',_'superC',_'breadB') = 690
#
# _C31: production_(6,_'factoryA',_'superA',_'breadA')
#  + production_(6,_'factoryB',_'superA',_'breadA') = 680
#
# _C32: production_(6,_'factoryA',_'superA',_'breadB')
#  + production_(6,_'factoryB',_'superA',_'breadB') = 660
#
# _C33: production_(6,_'factoryA',_'superB',_'breadA')
#  + production_(6,_'factoryB',_'superB',_'breadA') = 710
#
# _C34: production_(6,_'factoryA',_'superB',_'breadB')
#  + production_(6,_'factoryB',_'superB',_'breadB') = 700
#
# _C35: production_(6,_'factoryA',_'superC',_'breadA')
#  + production_(6,_'factoryB',_'superC',_'breadA') = 690
#
# _C36: production_(6,_'factoryA',_'superC',_'breadB')
#  + production_(6,_'factoryB',_'superC',_'breadB') = 690
#
# _C37: production_(7,_'factoryA',_'superA',_'breadA')
#  + production_(7,_'factoryB',_'superA',_'breadA') = 690
#
# _C38: production_(7,_'factoryA',_'superA',_'breadB')
#  + production_(7,_'factoryB',_'superA',_'breadB') = 780
#
# _C39: production_(7,_'factoryA',_'superB',_'breadA')
#  + production_(7,_'factoryB',_'superB',_'breadA') = 700
#
# _C40: production_(7,_'factoryA',_'superB',_'breadB')
#  + production_(7,_'factoryB',_'superB',_'breadB') = 790
#
# _C41: production_(7,_'factoryA',_'superC',_'breadA')
#  + production_(7,_'factoryB',_'superC',_'breadA') = 660
#
# _C42: production_(7,_'factoryA',_'superC',_'breadB')
#  + production_(7,_'factoryB',_'superC',_'breadB') = 710
#
# _C43: production_(8,_'factoryA',_'superA',_'breadA')
#  + production_(8,_'factoryB',_'superA',_'breadA') = 750
#
# _C44: production_(8,_'factoryA',_'superA',_'breadB')
#  + production_(8,_'factoryB',_'superA',_'breadB') = 710
#
# _C45: production_(8,_'factoryA',_'superB',_'breadA')
#  + production_(8,_'factoryB',_'superB',_'breadA') = 790
#
# _C46: production_(8,_'factoryA',_'superB',_'breadB')
#  + production_(8,_'factoryB',_'superB',_'breadB') = 780
#
# _C47: production_(8,_'factoryA',_'superC',_'breadA')
#  + production_(8,_'factoryB',_'superC',_'breadA') = 700
#
# _C48: production_(8,_'factoryA',_'superC',_'breadB')
#  + production_(8,_'factoryB',_'superC',_'breadB') = 700
#
# _C49: production_(9,_'factoryA',_'superA',_'breadA')
#  + production_(9,_'factoryB',_'superA',_'breadA') = 710
#
# _C50: production_(9,_'factoryA',_'superA',_'breadB')
#  + production_(9,_'factoryB',_'superA',_'breadB') = 700
#
# _C51: production_(9,_'factoryA',_'superB',_'breadA')
#  + production_(9,_'factoryB',_'superB',_'breadA') = 780
#
# _C52: production_(9,_'factoryA',_'superB',_'breadB')
#  + production_(9,_'factoryB',_'superB',_'breadB') = 710
#
# _C53: production_(9,_'factoryA',_'superC',_'breadA')
#  + production_(9,_'factoryB',_'superC',_'breadA') = 710
#
# _C54: production_(9,_'factoryA',_'superC',_'breadB')
#  + production_(9,_'factoryB',_'superC',_'breadB') = 730
#
# _C55: production_(10,_'factoryA',_'superA',_'breadA')
#  + production_(10,_'factoryB',_'superA',_'breadA') = 660
#
# _C56: production_(10,_'factoryA',_'superA',_'breadB')
#  + production_(10,_'factoryB',_'superA',_'breadB') = 690
#
# _C57: production_(10,_'factoryA',_'superB',_'breadA')
#  + production_(10,_'factoryB',_'superB',_'breadA') = 660
#
# _C58: production_(10,_'factoryA',_'superB',_'breadB')
#  + production_(10,_'factoryB',_'superB',_'breadB') = 710
#
# _C59: production_(10,_'factoryA',_'superC',_'breadA')
#  + production_(10,_'factoryB',_'superC',_'breadA') = 700
#
# _C60: production_(10,_'factoryA',_'superC',_'breadB')
#  + production_(10,_'factoryB',_'superC',_'breadB') = 700
#
# _C61: production_(11,_'factoryA',_'superA',_'breadA')
#  + production_(11,_'factoryB',_'superA',_'breadA') = 770
#
# _C62: production_(11,_'factoryA',_'superA',_'breadB')
#  + production_(11,_'factoryB',_'superA',_'breadB') = 690
#
# _C63: production_(11,_'factoryA',_'superB',_'breadA')
#  + production_(11,_'factoryB',_'superB',_'breadA') = 750
#
# _C64: production_(11,_'factoryA',_'superB',_'breadB')
#  + production_(11,_'factoryB',_'superB',_'breadB') = 680
#
# _C65: production_(11,_'factoryA',_'superC',_'breadA')
#  + production_(11,_'factoryB',_'superC',_'breadA') = 700
#
# _C66: production_(11,_'factoryA',_'superC',_'breadB')
#  + production_(11,_'factoryB',_'superC',_'breadB') = 680
#
# _C67: production_(12,_'factoryA',_'superA',_'breadA')
#  + production_(12,_'factoryB',_'superA',_'breadA') = 680
#
# _C68: production_(12,_'factoryA',_'superA',_'breadB')
#  + production_(12,_'factoryB',_'superA',_'breadB') = 760
#
# _C69: production_(12,_'factoryA',_'superB',_'breadA')
#  + production_(12,_'factoryB',_'superB',_'breadA') = 770
#
# _C70: production_(12,_'factoryA',_'superB',_'breadB')
#  + production_(12,_'factoryB',_'superB',_'breadB') = 690
#
# _C71: production_(12,_'factoryA',_'superC',_'breadA')
#  + production_(12,_'factoryB',_'superC',_'breadA') = 690
#
# _C72: production_(12,_'factoryA',_'superC',_'breadB')
#  + production_(12,_'factoryB',_'superC',_'breadB') = 690
#
# _C73: - 700 logistic_status_(1,_'factoryA',_'superA')
#  + production_(1,_'factoryA',_'superA',_'breadA') = 0
#
# _C74: - 620 logistic_status_(1,_'factoryA',_'superA')
#  + production_(1,_'factoryA',_'superA',_'breadB') = 0
#
# _C75: - 780 logistic_status_(2,_'factoryA',_'superA')
#  + production_(2,_'factoryA',_'superA',_'breadA') = 0
#
# _C76: - 700 logistic_status_(2,_'factoryA',_'superA')
#  + production_(2,_'factoryA',_'superA',_'breadB') = 0
#
# _C77: - 730 logistic_status_(3,_'factoryA',_'superA')
#  + production_(3,_'factoryA',_'superA',_'breadA') = 0
#
# _C78: - 600 logistic_status_(3,_'factoryA',_'superA')
#  + production_(3,_'factoryA',_'superA',_'breadB') = 0
#
# _C79: - 710 logistic_status_(4,_'factoryA',_'superA')
#  + production_(4,_'factoryA',_'superA',_'breadA') = 0
#
# _C80: - 680 logistic_status_(4,_'factoryA',_'superA')
#  + production_(4,_'factoryA',_'superA',_'breadB') = 0
#
# _C81: - 670 logistic_status_(5,_'factoryA',_'superA')
#  + production_(5,_'factoryA',_'superA',_'breadA') = 0
#
# _C82: - 790 logistic_status_(5,_'factoryA',_'superA')
#  + production_(5,_'factoryA',_'superA',_'breadB') = 0
#
# _C83: - 680 logistic_status_(6,_'factoryA',_'superA')
#  + production_(6,_'factoryA',_'superA',_'breadA') = 0
#
# _C84: - 660 logistic_status_(6,_'factoryA',_'superA')
#  + production_(6,_'factoryA',_'superA',_'breadB') = 0
#
# _C85: - 690 logistic_status_(7,_'factoryA',_'superA')
#  + production_(7,_'factoryA',_'superA',_'breadA') = 0
#
# _C86: - 780 logistic_status_(7,_'factoryA',_'superA')
#  + production_(7,_'factoryA',_'superA',_'breadB') = 0
#
# _C87: - 750 logistic_status_(8,_'factoryA',_'superA')
#  + production_(8,_'factoryA',_'superA',_'breadA') = 0
#
# _C88: - 710 logistic_status_(8,_'factoryA',_'superA')
#  + production_(8,_'factoryA',_'superA',_'breadB') = 0
#
# _C89: - 710 logistic_status_(9,_'factoryA',_'superA')
#  + production_(9,_'factoryA',_'superA',_'breadA') = 0
#
# _C90: - 700 logistic_status_(9,_'factoryA',_'superA')
#  + production_(9,_'factoryA',_'superA',_'breadB') = 0
#
# _C91: - 660 logistic_status_(10,_'factoryA',_'superA')
#  + production_(10,_'factoryA',_'superA',_'breadA') = 0
#
# _C92: - 690 logistic_status_(10,_'factoryA',_'superA')
#  + production_(10,_'factoryA',_'superA',_'breadB') = 0
#
# _C93: - 770 logistic_status_(11,_'factoryA',_'superA')
#  + production_(11,_'factoryA',_'superA',_'breadA') = 0
#
# _C94: - 690 logistic_status_(11,_'factoryA',_'superA')
#  + production_(11,_'factoryA',_'superA',_'breadB') = 0
#
# _C95: - 680 logistic_status_(12,_'factoryA',_'superA')
#  + production_(12,_'factoryA',_'superA',_'breadA') = 0
#
# _C96: - 760 logistic_status_(12,_'factoryA',_'superA')
#  + production_(12,_'factoryA',_'superA',_'breadB') = 0
#
# _C97: - 710 logistic_status_(1,_'factoryA',_'superB')
#  + production_(1,_'factoryA',_'superB',_'breadA') = 0
#
# _C98: - 770 logistic_status_(1,_'factoryA',_'superB')
#  + production_(1,_'factoryA',_'superB',_'breadB') = 0
#
# _C99: - 730 logistic_status_(2,_'factoryA',_'superB')
#  + production_(2,_'factoryA',_'superB',_'breadA') = 0
#
# _C100: - 670 logistic_status_(2,_'factoryA',_'superB')
#  + production_(2,_'factoryA',_'superB',_'breadB') = 0
#
# _C101: - 680 logistic_status_(3,_'factoryA',_'superB')
#  + production_(3,_'factoryA',_'superB',_'breadA') = 0
#
# _C102: - 650 logistic_status_(3,_'factoryA',_'superB')
#  + production_(3,_'factoryA',_'superB',_'breadB') = 0
#
# _C103: - 680 logistic_status_(4,_'factoryA',_'superB')
#  + production_(4,_'factoryA',_'superB',_'breadA') = 0
#
# _C104: - 740 logistic_status_(4,_'factoryA',_'superB')
#  + production_(4,_'factoryA',_'superB',_'breadB') = 0
#
# _C105: - 700 logistic_status_(5,_'factoryA',_'superB')
#  + production_(5,_'factoryA',_'superB',_'breadA') = 0
#
# _C106: - 680 logistic_status_(5,_'factoryA',_'superB')
#  + production_(5,_'factoryA',_'superB',_'breadB') = 0
#
# _C107: - 710 logistic_status_(6,_'factoryA',_'superB')
#  + production_(6,_'factoryA',_'superB',_'breadA') = 0
#
# _C108: - 700 logistic_status_(6,_'factoryA',_'superB')
#  + production_(6,_'factoryA',_'superB',_'breadB') = 0
#
# _C109: - 700 logistic_status_(7,_'factoryA',_'superB')
#  + production_(7,_'factoryA',_'superB',_'breadA') = 0
#
# _C110: - 790 logistic_status_(7,_'factoryA',_'superB')
#  + production_(7,_'factoryA',_'superB',_'breadB') = 0
#
# _C111: - 790 logistic_status_(8,_'factoryA',_'superB')
#  + production_(8,_'factoryA',_'superB',_'breadA') = 0
#
# _C112: - 780 logistic_status_(8,_'factoryA',_'superB')
#  + production_(8,_'factoryA',_'superB',_'breadB') = 0
#
# _C113: - 780 logistic_status_(9,_'factoryA',_'superB')
#  + production_(9,_'factoryA',_'superB',_'breadA') = 0
#
# _C114: - 710 logistic_status_(9,_'factoryA',_'superB')
#  + production_(9,_'factoryA',_'superB',_'breadB') = 0
#
# _C115: - 660 logistic_status_(10,_'factoryA',_'superB')
#  + production_(10,_'factoryA',_'superB',_'breadA') = 0
#
# _C116: - 710 logistic_status_(10,_'factoryA',_'superB')
#  + production_(10,_'factoryA',_'superB',_'breadB') = 0
#
# _C117: - 750 logistic_status_(11,_'factoryA',_'superB')
#  + production_(11,_'factoryA',_'superB',_'breadA') = 0
#
# _C118: - 680 logistic_status_(11,_'factoryA',_'superB')
#  + production_(11,_'factoryA',_'superB',_'breadB') = 0
#
# _C119: - 770 logistic_status_(12,_'factoryA',_'superB')
#  + production_(12,_'factoryA',_'superB',_'breadA') = 0
#
# _C120: - 690 logistic_status_(12,_'factoryA',_'superB')
#  + production_(12,_'factoryA',_'superB',_'breadB') = 0
#
# _C121: - 770 logistic_status_(1,_'factoryA',_'superC')
#  + production_(1,_'factoryA',_'superC',_'breadA') = 0
#
# _C122: - 680 logistic_status_(1,_'factoryA',_'superC')
#  + production_(1,_'factoryA',_'superC',_'breadB') = 0
#
# _C123: - 760 logistic_status_(2,_'factoryA',_'superC')
#  + production_(2,_'factoryA',_'superC',_'breadA') = 0
#
# _C124: - 650 logistic_status_(2,_'factoryA',_'superC')
#  + production_(2,_'factoryA',_'superC',_'breadB') = 0
#
# _C125: - 750 logistic_status_(3,_'factoryA',_'superC')
#  + production_(3,_'factoryA',_'superC',_'breadA') = 0
#
# _C126: - 670 logistic_status_(3,_'factoryA',_'superC')
#  + production_(3,_'factoryA',_'superC',_'breadB') = 0
#
# _C127: - 680 logistic_status_(4,_'factoryA',_'superC')
#  + production_(4,_'factoryA',_'superC',_'breadA') = 0
#
# _C128: - 680 logistic_status_(4,_'factoryA',_'superC')
#  + production_(4,_'factoryA',_'superC',_'breadB') = 0
#
# _C129: - 680 logistic_status_(5,_'factoryA',_'superC')
#  + production_(5,_'factoryA',_'superC',_'breadA') = 0
#
# _C130: - 690 logistic_status_(5,_'factoryA',_'superC')
#  + production_(5,_'factoryA',_'superC',_'breadB') = 0
#
# _C131: - 690 logistic_status_(6,_'factoryA',_'superC')
#  + production_(6,_'factoryA',_'superC',_'breadA') = 0
#
# _C132: - 690 logistic_status_(6,_'factoryA',_'superC')
#  + production_(6,_'factoryA',_'superC',_'breadB') = 0
#
# _C133: - 660 logistic_status_(7,_'factoryA',_'superC')
#  + production_(7,_'factoryA',_'superC',_'breadA') = 0
#
# _C134: - 710 logistic_status_(7,_'factoryA',_'superC')
#  + production_(7,_'factoryA',_'superC',_'breadB') = 0
#
# _C135: - 700 logistic_status_(8,_'factoryA',_'superC')
#  + production_(8,_'factoryA',_'superC',_'breadA') = 0
#
# _C136: - 700 logistic_status_(8,_'factoryA',_'superC')
#  + production_(8,_'factoryA',_'superC',_'breadB') = 0
#
# _C137: - 710 logistic_status_(9,_'factoryA',_'superC')
#  + production_(9,_'factoryA',_'superC',_'breadA') = 0
#
# _C138: - 730 logistic_status_(9,_'factoryA',_'superC')
#  + production_(9,_'factoryA',_'superC',_'breadB') = 0
#
# _C139: - 700 logistic_status_(10,_'factoryA',_'superC')
#  + production_(10,_'factoryA',_'superC',_'breadA') = 0
#
# _C140: - 700 logistic_status_(10,_'factoryA',_'superC')
#  + production_(10,_'factoryA',_'superC',_'breadB') = 0
#
# _C141: - 700 logistic_status_(11,_'factoryA',_'superC')
#  + production_(11,_'factoryA',_'superC',_'breadA') = 0
#
# _C142: - 680 logistic_status_(11,_'factoryA',_'superC')
#  + production_(11,_'factoryA',_'superC',_'breadB') = 0
#
# _C143: - 690 logistic_status_(12,_'factoryA',_'superC')
#  + production_(12,_'factoryA',_'superC',_'breadA') = 0
#
# _C144: - 690 logistic_status_(12,_'factoryA',_'superC')
#  + production_(12,_'factoryA',_'superC',_'breadB') = 0
#
# _C145: - 700 logistic_status_(1,_'factoryB',_'superA')
#  + production_(1,_'factoryB',_'superA',_'breadA') = 0
#
# _C146: - 620 logistic_status_(1,_'factoryB',_'superA')
#  + production_(1,_'factoryB',_'superA',_'breadB') = 0
#
# _C147: - 780 logistic_status_(2,_'factoryB',_'superA')
#  + production_(2,_'factoryB',_'superA',_'breadA') = 0
#
# _C148: - 700 logistic_status_(2,_'factoryB',_'superA')
#  + production_(2,_'factoryB',_'superA',_'breadB') = 0
#
# _C149: - 730 logistic_status_(3,_'factoryB',_'superA')
#  + production_(3,_'factoryB',_'superA',_'breadA') = 0
#
# _C150: - 600 logistic_status_(3,_'factoryB',_'superA')
#  + production_(3,_'factoryB',_'superA',_'breadB') = 0
#
# _C151: - 710 logistic_status_(4,_'factoryB',_'superA')
#  + production_(4,_'factoryB',_'superA',_'breadA') = 0
#
# _C152: - 680 logistic_status_(4,_'factoryB',_'superA')
#  + production_(4,_'factoryB',_'superA',_'breadB') = 0
#
# _C153: - 670 logistic_status_(5,_'factoryB',_'superA')
#  + production_(5,_'factoryB',_'superA',_'breadA') = 0
#
# _C154: - 790 logistic_status_(5,_'factoryB',_'superA')
#  + production_(5,_'factoryB',_'superA',_'breadB') = 0
#
# _C155: - 680 logistic_status_(6,_'factoryB',_'superA')
#  + production_(6,_'factoryB',_'superA',_'breadA') = 0
#
# _C156: - 660 logistic_status_(6,_'factoryB',_'superA')
#  + production_(6,_'factoryB',_'superA',_'breadB') = 0
#
# _C157: - 690 logistic_status_(7,_'factoryB',_'superA')
#  + production_(7,_'factoryB',_'superA',_'breadA') = 0
#
# _C158: - 780 logistic_status_(7,_'factoryB',_'superA')
#  + production_(7,_'factoryB',_'superA',_'breadB') = 0
#
# _C159: - 750 logistic_status_(8,_'factoryB',_'superA')
#  + production_(8,_'factoryB',_'superA',_'breadA') = 0
#
# _C160: - 710 logistic_status_(8,_'factoryB',_'superA')
#  + production_(8,_'factoryB',_'superA',_'breadB') = 0
#
# _C161: - 710 logistic_status_(9,_'factoryB',_'superA')
#  + production_(9,_'factoryB',_'superA',_'breadA') = 0
#
# _C162: - 700 logistic_status_(9,_'factoryB',_'superA')
#  + production_(9,_'factoryB',_'superA',_'breadB') = 0
#
# _C163: - 660 logistic_status_(10,_'factoryB',_'superA')
#  + production_(10,_'factoryB',_'superA',_'breadA') = 0
#
# _C164: - 690 logistic_status_(10,_'factoryB',_'superA')
#  + production_(10,_'factoryB',_'superA',_'breadB') = 0
#
# _C165: - 770 logistic_status_(11,_'factoryB',_'superA')
#  + production_(11,_'factoryB',_'superA',_'breadA') = 0
#
# _C166: - 690 logistic_status_(11,_'factoryB',_'superA')
#  + production_(11,_'factoryB',_'superA',_'breadB') = 0
#
# _C167: - 680 logistic_status_(12,_'factoryB',_'superA')
#  + production_(12,_'factoryB',_'superA',_'breadA') = 0
#
# _C168: - 760 logistic_status_(12,_'factoryB',_'superA')
#  + production_(12,_'factoryB',_'superA',_'breadB') = 0
#
# _C169: - 710 logistic_status_(1,_'factoryB',_'superB')
#  + production_(1,_'factoryB',_'superB',_'breadA') = 0
#
# _C170: - 770 logistic_status_(1,_'factoryB',_'superB')
#  + production_(1,_'factoryB',_'superB',_'breadB') = 0
#
# _C171: - 730 logistic_status_(2,_'factoryB',_'superB')
#  + production_(2,_'factoryB',_'superB',_'breadA') = 0
#
# _C172: - 670 logistic_status_(2,_'factoryB',_'superB')
#  + production_(2,_'factoryB',_'superB',_'breadB') = 0
#
# _C173: - 680 logistic_status_(3,_'factoryB',_'superB')
#  + production_(3,_'factoryB',_'superB',_'breadA') = 0
#
# _C174: - 650 logistic_status_(3,_'factoryB',_'superB')
#  + production_(3,_'factoryB',_'superB',_'breadB') = 0
#
# _C175: - 680 logistic_status_(4,_'factoryB',_'superB')
#  + production_(4,_'factoryB',_'superB',_'breadA') = 0
#
# _C176: - 740 logistic_status_(4,_'factoryB',_'superB')
#  + production_(4,_'factoryB',_'superB',_'breadB') = 0
#
# _C177: - 700 logistic_status_(5,_'factoryB',_'superB')
#  + production_(5,_'factoryB',_'superB',_'breadA') = 0
#
# _C178: - 680 logistic_status_(5,_'factoryB',_'superB')
#  + production_(5,_'factoryB',_'superB',_'breadB') = 0
#
# _C179: - 710 logistic_status_(6,_'factoryB',_'superB')
#  + production_(6,_'factoryB',_'superB',_'breadA') = 0
#
# _C180: - 700 logistic_status_(6,_'factoryB',_'superB')
#  + production_(6,_'factoryB',_'superB',_'breadB') = 0
#
# _C181: - 700 logistic_status_(7,_'factoryB',_'superB')
#  + production_(7,_'factoryB',_'superB',_'breadA') = 0
#
# _C182: - 790 logistic_status_(7,_'factoryB',_'superB')
#  + production_(7,_'factoryB',_'superB',_'breadB') = 0
#
# _C183: - 790 logistic_status_(8,_'factoryB',_'superB')
#  + production_(8,_'factoryB',_'superB',_'breadA') = 0
#
# _C184: - 780 logistic_status_(8,_'factoryB',_'superB')
#  + production_(8,_'factoryB',_'superB',_'breadB') = 0
#
# _C185: - 780 logistic_status_(9,_'factoryB',_'superB')
#  + production_(9,_'factoryB',_'superB',_'breadA') = 0
#
# _C186: - 710 logistic_status_(9,_'factoryB',_'superB')
#  + production_(9,_'factoryB',_'superB',_'breadB') = 0
#
# _C187: - 660 logistic_status_(10,_'factoryB',_'superB')
#  + production_(10,_'factoryB',_'superB',_'breadA') = 0
#
# _C188: - 710 logistic_status_(10,_'factoryB',_'superB')
#  + production_(10,_'factoryB',_'superB',_'breadB') = 0
#
# _C189: - 750 logistic_status_(11,_'factoryB',_'superB')
#  + production_(11,_'factoryB',_'superB',_'breadA') = 0
#
# _C190: - 680 logistic_status_(11,_'factoryB',_'superB')
#  + production_(11,_'factoryB',_'superB',_'breadB') = 0
#
# _C191: - 770 logistic_status_(12,_'factoryB',_'superB')
#  + production_(12,_'factoryB',_'superB',_'breadA') = 0
#
# _C192: - 690 logistic_status_(12,_'factoryB',_'superB')
#  + production_(12,_'factoryB',_'superB',_'breadB') = 0
#
# _C193: - 770 logistic_status_(1,_'factoryB',_'superC')
#  + production_(1,_'factoryB',_'superC',_'breadA') = 0
#
# _C194: - 680 logistic_status_(1,_'factoryB',_'superC')
#  + production_(1,_'factoryB',_'superC',_'breadB') = 0
#
# _C195: - 760 logistic_status_(2,_'factoryB',_'superC')
#  + production_(2,_'factoryB',_'superC',_'breadA') = 0
#
# _C196: - 650 logistic_status_(2,_'factoryB',_'superC')
#  + production_(2,_'factoryB',_'superC',_'breadB') = 0
#
# _C197: - 750 logistic_status_(3,_'factoryB',_'superC')
#  + production_(3,_'factoryB',_'superC',_'breadA') = 0
#
# _C198: - 670 logistic_status_(3,_'factoryB',_'superC')
#  + production_(3,_'factoryB',_'superC',_'breadB') = 0
#
# _C199: - 680 logistic_status_(4,_'factoryB',_'superC')
#  + production_(4,_'factoryB',_'superC',_'breadA') = 0
#
# _C200: - 680 logistic_status_(4,_'factoryB',_'superC')
#  + production_(4,_'factoryB',_'superC',_'breadB') = 0
#
# _C201: - 680 logistic_status_(5,_'factoryB',_'superC')
#  + production_(5,_'factoryB',_'superC',_'breadA') = 0
#
# _C202: - 690 logistic_status_(5,_'factoryB',_'superC')
#  + production_(5,_'factoryB',_'superC',_'breadB') = 0
#
# _C203: - 690 logistic_status_(6,_'factoryB',_'superC')
#  + production_(6,_'factoryB',_'superC',_'breadA') = 0
#
# _C204: - 690 logistic_status_(6,_'factoryB',_'superC')
#  + production_(6,_'factoryB',_'superC',_'breadB') = 0
#
# _C205: - 660 logistic_status_(7,_'factoryB',_'superC')
#  + production_(7,_'factoryB',_'superC',_'breadA') = 0
#
# _C206: - 710 logistic_status_(7,_'factoryB',_'superC')
#  + production_(7,_'factoryB',_'superC',_'breadB') = 0
#
# _C207: - 700 logistic_status_(8,_'factoryB',_'superC')
#  + production_(8,_'factoryB',_'superC',_'breadA') = 0
#
# _C208: - 700 logistic_status_(8,_'factoryB',_'superC')
#  + production_(8,_'factoryB',_'superC',_'breadB') = 0
#
# _C209: - 710 logistic_status_(9,_'factoryB',_'superC')
#  + production_(9,_'factoryB',_'superC',_'breadA') = 0
#
# _C210: - 730 logistic_status_(9,_'factoryB',_'superC')
#  + production_(9,_'factoryB',_'superC',_'breadB') = 0
#
# _C211: - 700 logistic_status_(10,_'factoryB',_'superC')
#  + production_(10,_'factoryB',_'superC',_'breadA') = 0
#
# _C212: - 700 logistic_status_(10,_'factoryB',_'superC')
#  + production_(10,_'factoryB',_'superC',_'breadB') = 0
#
# _C213: - 700 logistic_status_(11,_'factoryB',_'superC')
#  + production_(11,_'factoryB',_'superC',_'breadA') = 0
#
# _C214: - 680 logistic_status_(11,_'factoryB',_'superC')
#  + production_(11,_'factoryB',_'superC',_'breadB') = 0
#
# _C215: - 690 logistic_status_(12,_'factoryB',_'superC')
#  + production_(12,_'factoryB',_'superC',_'breadA') = 0
#
# _C216: - 690 logistic_status_(12,_'factoryB',_'superC')
#  + production_(12,_'factoryB',_'superC',_'breadB') = 0
#
# _C217: factory_status_(1,_'factoryB') = 0
#
# _C218: factory_status_(2,_'factoryB') = 0
#
# _C219: logistic_status_(1,_'factoryB',_'superA') = 0
#
# _C220: logistic_status_(1,_'factoryB',_'superB') = 0
#
# _C221: logistic_status_(1,_'factoryB',_'superC') = 0
#
# _C222: logistic_status_(2,_'factoryB',_'superA') = 0
#
# _C223: logistic_status_(2,_'factoryB',_'superB') = 0
#
# _C224: logistic_status_(2,_'factoryB',_'superC') = 0
#
# _C225: factory_status_(1,_'factoryA') + factory_status_(1,_'factoryB') >= 1
#
# _C226: factory_status_(2,_'factoryA') + factory_status_(2,_'factoryB') >= 1
#
# _C227: factory_status_(3,_'factoryA') + factory_status_(3,_'factoryB') >= 1
#
# _C228: factory_status_(4,_'factoryA') + factory_status_(4,_'factoryB') >= 1
#
# _C229: factory_status_(5,_'factoryA') + factory_status_(5,_'factoryB') >= 1
#
# _C230: factory_status_(6,_'factoryA') + factory_status_(6,_'factoryB') >= 1
#
# _C231: factory_status_(7,_'factoryA') + factory_status_(7,_'factoryB') >= 1
#
# _C232: factory_status_(8,_'factoryA') + factory_status_(8,_'factoryB') >= 1
#
# _C233: factory_status_(9,_'factoryA') + factory_status_(9,_'factoryB') >= 1
#
# _C234: factory_status_(10,_'factoryA') + factory_status_(10,_'factoryB') >= 1
#
# _C235: factory_status_(11,_'factoryA') + factory_status_(11,_'factoryB') >= 1
#
# _C236: factory_status_(12,_'factoryA') + factory_status_(12,_'factoryB') >= 1
#
# VARIABLES
# 0 <= factory_status_(1,_'factoryA') <= 1 Integer
# 0 <= factory_status_(1,_'factoryB') <= 1 Integer
# 0 <= factory_status_(10,_'factoryA') <= 1 Integer
# 0 <= factory_status_(10,_'factoryB') <= 1 Integer
# 0 <= factory_status_(11,_'factoryA') <= 1 Integer
# 0 <= factory_status_(11,_'factoryB') <= 1 Integer
# 0 <= factory_status_(12,_'factoryA') <= 1 Integer
# 0 <= factory_status_(12,_'factoryB') <= 1 Integer
# 0 <= factory_status_(2,_'factoryA') <= 1 Integer
# 0 <= factory_status_(2,_'factoryB') <= 1 Integer
# 0 <= factory_status_(3,_'factoryA') <= 1 Integer
# 0 <= factory_status_(3,_'factoryB') <= 1 Integer
# 0 <= factory_status_(4,_'factoryA') <= 1 Integer
# 0 <= factory_status_(4,_'factoryB') <= 1 Integer
# 0 <= factory_status_(5,_'factoryA') <= 1 Integer
# 0 <= factory_status_(5,_'factoryB') <= 1 Integer
# 0 <= factory_status_(6,_'factoryA') <= 1 Integer
# 0 <= factory_status_(6,_'factoryB') <= 1 Integer
# 0 <= factory_status_(7,_'factoryA') <= 1 Integer
# 0 <= factory_status_(7,_'factoryB') <= 1 Integer
# 0 <= factory_status_(8,_'factoryA') <= 1 Integer
# 0 <= factory_status_(8,_'factoryB') <= 1 Integer
# 0 <= factory_status_(9,_'factoryA') <= 1 Integer
# 0 <= factory_status_(9,_'factoryB') <= 1 Integer
# 0 <= logistic_status_(1,_'factoryA',_'superA') <= 1 Integer
# 0 <= logistic_status_(1,_'factoryA',_'superB') <= 1 Integer
# 0 <= logistic_status_(1,_'factoryA',_'superC') <= 1 Integer
# 0 <= logistic_status_(1,_'factoryB',_'superA') <= 1 Integer
# 0 <= logistic_status_(1,_'factoryB',_'superB') <= 1 Integer
# 0 <= logistic_status_(1,_'factoryB',_'superC') <= 1 Integer
# 0 <= logistic_status_(10,_'factoryA',_'superA') <= 1 Integer
# 0 <= logistic_status_(10,_'factoryA',_'superB') <= 1 Integer
# 0 <= logistic_status_(10,_'factoryA',_'superC') <= 1 Integer
# 0 <= logistic_status_(10,_'factoryB',_'superA') <= 1 Integer
# 0 <= logistic_status_(10,_'factoryB',_'superB') <= 1 Integer
# 0 <= logistic_status_(10,_'factoryB',_'superC') <= 1 Integer
# 0 <= logistic_status_(11,_'factoryA',_'superA') <= 1 Integer
# 0 <= logistic_status_(11,_'factoryA',_'superB') <= 1 Integer
# 0 <= logistic_status_(11,_'factoryA',_'superC') <= 1 Integer
# 0 <= logistic_status_(11,_'factoryB',_'superA') <= 1 Integer
# 0 <= logistic_status_(11,_'factoryB',_'superB') <= 1 Integer
# 0 <= logistic_status_(11,_'factoryB',_'superC') <= 1 Integer
# 0 <= logistic_status_(12,_'factoryA',_'superA') <= 1 Integer
# 0 <= logistic_status_(12,_'factoryA',_'superB') <= 1 Integer
# 0 <= logistic_status_(12,_'factoryA',_'superC') <= 1 Integer
# 0 <= logistic_status_(12,_'factoryB',_'superA') <= 1 Integer
# 0 <= logistic_status_(12,_'factoryB',_'superB') <= 1 Integer
# 0 <= logistic_status_(12,_'factoryB',_'superC') <= 1 Integer
# 0 <= logistic_status_(2,_'factoryA',_'superA') <= 1 Integer
# 0 <= logistic_status_(2,_'factoryA',_'superB') <= 1 Integer
# 0 <= logistic_status_(2,_'factoryA',_'superC') <= 1 Integer
# 0 <= logistic_status_(2,_'factoryB',_'superA') <= 1 Integer
# 0 <= logistic_status_(2,_'factoryB',_'superB') <= 1 Integer
# 0 <= logistic_status_(2,_'factoryB',_'superC') <= 1 Integer
# 0 <= logistic_status_(3,_'factoryA',_'superA') <= 1 Integer
# 0 <= logistic_status_(3,_'factoryA',_'superB') <= 1 Integer
# 0 <= logistic_status_(3,_'factoryA',_'superC') <= 1 Integer
# 0 <= logistic_status_(3,_'factoryB',_'superA') <= 1 Integer
# 0 <= logistic_status_(3,_'factoryB',_'superB') <= 1 Integer
# 0 <= logistic_status_(3,_'factoryB',_'superC') <= 1 Integer
# 0 <= logistic_status_(4,_'factoryA',_'superA') <= 1 Integer
# 0 <= logistic_status_(4,_'factoryA',_'superB') <= 1 Integer
# 0 <= logistic_status_(4,_'factoryA',_'superC') <= 1 Integer
# 0 <= logistic_status_(4,_'factoryB',_'superA') <= 1 Integer
# 0 <= logistic_status_(4,_'factoryB',_'superB') <= 1 Integer
# 0 <= logistic_status_(4,_'factoryB',_'superC') <= 1 Integer
# 0 <= logistic_status_(5,_'factoryA',_'superA') <= 1 Integer
# 0 <= logistic_status_(5,_'factoryA',_'superB') <= 1 Integer
# 0 <= logistic_status_(5,_'factoryA',_'superC') <= 1 Integer
# 0 <= logistic_status_(5,_'factoryB',_'superA') <= 1 Integer
# 0 <= logistic_status_(5,_'factoryB',_'superB') <= 1 Integer
# 0 <= logistic_status_(5,_'factoryB',_'superC') <= 1 Integer
# 0 <= logistic_status_(6,_'factoryA',_'superA') <= 1 Integer
# 0 <= logistic_status_(6,_'factoryA',_'superB') <= 1 Integer
# 0 <= logistic_status_(6,_'factoryA',_'superC') <= 1 Integer
# 0 <= logistic_status_(6,_'factoryB',_'superA') <= 1 Integer
# 0 <= logistic_status_(6,_'factoryB',_'superB') <= 1 Integer
# 0 <= logistic_status_(6,_'factoryB',_'superC') <= 1 Integer
# 0 <= logistic_status_(7,_'factoryA',_'superA') <= 1 Integer
# 0 <= logistic_status_(7,_'factoryA',_'superB') <= 1 Integer
# 0 <= logistic_status_(7,_'factoryA',_'superC') <= 1 Integer
# 0 <= logistic_status_(7,_'factoryB',_'superA') <= 1 Integer
# 0 <= logistic_status_(7,_'factoryB',_'superB') <= 1 Integer
# 0 <= logistic_status_(7,_'factoryB',_'superC') <= 1 Integer
# 0 <= logistic_status_(8,_'factoryA',_'superA') <= 1 Integer
# 0 <= logistic_status_(8,_'factoryA',_'superB') <= 1 Integer
# 0 <= logistic_status_(8,_'factoryA',_'superC') <= 1 Integer
# 0 <= logistic_status_(8,_'factoryB',_'superA') <= 1 Integer
# 0 <= logistic_status_(8,_'factoryB',_'superB') <= 1 Integer
# 0 <= logistic_status_(8,_'factoryB',_'superC') <= 1 Integer
# 0 <= logistic_status_(9,_'factoryA',_'superA') <= 1 Integer
# 0 <= logistic_status_(9,_'factoryA',_'superB') <= 1 Integer
# 0 <= logistic_status_(9,_'factoryA',_'superC') <= 1 Integer
# 0 <= logistic_status_(9,_'factoryB',_'superA') <= 1 Integer
# 0 <= logistic_status_(9,_'factoryB',_'superB') <= 1 Integer
# 0 <= logistic_status_(9,_'factoryB',_'superC') <= 1 Integer
# 0 <= production_(1,_'factoryA',_'superA',_'breadA') Integer
# 0 <= production_(1,_'factoryA',_'superA',_'breadB') Integer
# 0 <= production_(1,_'factoryA',_'superB',_'breadA') Integer
# 0 <= production_(1,_'factoryA',_'superB',_'breadB') Integer
# 0 <= production_(1,_'factoryA',_'superC',_'breadA') Integer
# 0 <= production_(1,_'factoryA',_'superC',_'breadB') Integer
# 0 <= production_(1,_'factoryB',_'superA',_'breadA') Integer
# 0 <= production_(1,_'factoryB',_'superA',_'breadB') Integer
# 0 <= production_(1,_'factoryB',_'superB',_'breadA') Integer
# 0 <= production_(1,_'factoryB',_'superB',_'breadB') Integer
# 0 <= production_(1,_'factoryB',_'superC',_'breadA') Integer
# 0 <= production_(1,_'factoryB',_'superC',_'breadB') Integer
# 0 <= production_(10,_'factoryA',_'superA',_'breadA') Integer
# 0 <= production_(10,_'factoryA',_'superA',_'breadB') Integer
# 0 <= production_(10,_'factoryA',_'superB',_'breadA') Integer
# 0 <= production_(10,_'factoryA',_'superB',_'breadB') Integer
# 0 <= production_(10,_'factoryA',_'superC',_'breadA') Integer
# 0 <= production_(10,_'factoryA',_'superC',_'breadB') Integer
# 0 <= production_(10,_'factoryB',_'superA',_'breadA') Integer
# 0 <= production_(10,_'factoryB',_'superA',_'breadB') Integer
# 0 <= production_(10,_'factoryB',_'superB',_'breadA') Integer
# 0 <= production_(10,_'factoryB',_'superB',_'breadB') Integer
# 0 <= production_(10,_'factoryB',_'superC',_'breadA') Integer
# 0 <= production_(10,_'factoryB',_'superC',_'breadB') Integer
# 0 <= production_(11,_'factoryA',_'superA',_'breadA') Integer
# 0 <= production_(11,_'factoryA',_'superA',_'breadB') Integer
# 0 <= production_(11,_'factoryA',_'superB',_'breadA') Integer
# 0 <= production_(11,_'factoryA',_'superB',_'breadB') Integer
# 0 <= production_(11,_'factoryA',_'superC',_'breadA') Integer
# 0 <= production_(11,_'factoryA',_'superC',_'breadB') Integer
# 0 <= production_(11,_'factoryB',_'superA',_'breadA') Integer
# 0 <= production_(11,_'factoryB',_'superA',_'breadB') Integer
# 0 <= production_(11,_'factoryB',_'superB',_'breadA') Integer
# 0 <= production_(11,_'factoryB',_'superB',_'breadB') Integer
# 0 <= production_(11,_'factoryB',_'superC',_'breadA') Integer
# 0 <= production_(11,_'factoryB',_'superC',_'breadB') Integer
# 0 <= production_(12,_'factoryA',_'superA',_'breadA') Integer
# 0 <= production_(12,_'factoryA',_'superA',_'breadB') Integer
# 0 <= production_(12,_'factoryA',_'superB',_'breadA') Integer
# 0 <= production_(12,_'factoryA',_'superB',_'breadB') Integer
# 0 <= production_(12,_'factoryA',_'superC',_'breadA') Integer
# 0 <= production_(12,_'factoryA',_'superC',_'breadB') Integer
# 0 <= production_(12,_'factoryB',_'superA',_'breadA') Integer
# 0 <= production_(12,_'factoryB',_'superA',_'breadB') Integer
# 0 <= production_(12,_'factoryB',_'superB',_'breadA') Integer
# 0 <= production_(12,_'factoryB',_'superB',_'breadB') Integer
# 0 <= production_(12,_'factoryB',_'superC',_'breadA') Integer
# 0 <= production_(12,_'factoryB',_'superC',_'breadB') Integer
# 0 <= production_(2,_'factoryA',_'superA',_'breadA') Integer
# 0 <= production_(2,_'factoryA',_'superA',_'breadB') Integer
# 0 <= production_(2,_'factoryA',_'superB',_'breadA') Integer
# 0 <= production_(2,_'factoryA',_'superB',_'breadB') Integer
# 0 <= production_(2,_'factoryA',_'superC',_'breadA') Integer
# 0 <= production_(2,_'factoryA',_'superC',_'breadB') Integer
# 0 <= production_(2,_'factoryB',_'superA',_'breadA') Integer
# 0 <= production_(2,_'factoryB',_'superA',_'breadB') Integer
# 0 <= production_(2,_'factoryB',_'superB',_'breadA') Integer
# 0 <= production_(2,_'factoryB',_'superB',_'breadB') Integer
# 0 <= production_(2,_'factoryB',_'superC',_'breadA') Integer
# 0 <= production_(2,_'factoryB',_'superC',_'breadB') Integer
# 0 <= production_(3,_'factoryA',_'superA',_'breadA') Integer
# 0 <= production_(3,_'factoryA',_'superA',_'breadB') Integer
# 0 <= production_(3,_'factoryA',_'superB',_'breadA') Integer
# 0 <= production_(3,_'factoryA',_'superB',_'breadB') Integer
# 0 <= production_(3,_'factoryA',_'superC',_'breadA') Integer
# 0 <= production_(3,_'factoryA',_'superC',_'breadB') Integer
# 0 <= production_(3,_'factoryB',_'superA',_'breadA') Integer
# 0 <= production_(3,_'factoryB',_'superA',_'breadB') Integer
# 0 <= production_(3,_'factoryB',_'superB',_'breadA') Integer
# 0 <= production_(3,_'factoryB',_'superB',_'breadB') Integer
# 0 <= production_(3,_'factoryB',_'superC',_'breadA') Integer
# 0 <= production_(3,_'factoryB',_'superC',_'breadB') Integer
# 0 <= production_(4,_'factoryA',_'superA',_'breadA') Integer
# 0 <= production_(4,_'factoryA',_'superA',_'breadB') Integer
# 0 <= production_(4,_'factoryA',_'superB',_'breadA') Integer
# 0 <= production_(4,_'factoryA',_'superB',_'breadB') Integer
# 0 <= production_(4,_'factoryA',_'superC',_'breadA') Integer
# 0 <= production_(4,_'factoryA',_'superC',_'breadB') Integer
# 0 <= production_(4,_'factoryB',_'superA',_'breadA') Integer
# 0 <= production_(4,_'factoryB',_'superA',_'breadB') Integer
# 0 <= production_(4,_'factoryB',_'superB',_'breadA') Integer
# 0 <= production_(4,_'factoryB',_'superB',_'breadB') Integer
# 0 <= production_(4,_'factoryB',_'superC',_'breadA') Integer
# 0 <= production_(4,_'factoryB',_'superC',_'breadB') Integer
# 0 <= production_(5,_'factoryA',_'superA',_'breadA') Integer
# 0 <= production_(5,_'factoryA',_'superA',_'breadB') Integer
# 0 <= production_(5,_'factoryA',_'superB',_'breadA') Integer
# 0 <= production_(5,_'factoryA',_'superB',_'breadB') Integer
# 0 <= production_(5,_'factoryA',_'superC',_'breadA') Integer
# 0 <= production_(5,_'factoryA',_'superC',_'breadB') Integer
# 0 <= production_(5,_'factoryB',_'superA',_'breadA') Integer
# 0 <= production_(5,_'factoryB',_'superA',_'breadB') Integer
# 0 <= production_(5,_'factoryB',_'superB',_'breadA') Integer
# 0 <= production_(5,_'factoryB',_'superB',_'breadB') Integer
# 0 <= production_(5,_'factoryB',_'superC',_'breadA') Integer
# 0 <= production_(5,_'factoryB',_'superC',_'breadB') Integer
# 0 <= production_(6,_'factoryA',_'superA',_'breadA') Integer
# 0 <= production_(6,_'factoryA',_'superA',_'breadB') Integer
# 0 <= production_(6,_'factoryA',_'superB',_'breadA') Integer
# 0 <= production_(6,_'factoryA',_'superB',_'breadB') Integer
# 0 <= production_(6,_'factoryA',_'superC',_'breadA') Integer
# 0 <= production_(6,_'factoryA',_'superC',_'breadB') Integer
# 0 <= production_(6,_'factoryB',_'superA',_'breadA') Integer
# 0 <= production_(6,_'factoryB',_'superA',_'breadB') Integer
# 0 <= production_(6,_'factoryB',_'superB',_'breadA') Integer
# 0 <= production_(6,_'factoryB',_'superB',_'breadB') Integer
# 0 <= production_(6,_'factoryB',_'superC',_'breadA') Integer
# 0 <= production_(6,_'factoryB',_'superC',_'breadB') Integer
# 0 <= production_(7,_'factoryA',_'superA',_'breadA') Integer
# 0 <= production_(7,_'factoryA',_'superA',_'breadB') Integer
# 0 <= production_(7,_'factoryA',_'superB',_'breadA') Integer
# 0 <= production_(7,_'factoryA',_'superB',_'breadB') Integer
# 0 <= production_(7,_'factoryA',_'superC',_'breadA') Integer
# 0 <= production_(7,_'factoryA',_'superC',_'breadB') Integer
# 0 <= production_(7,_'factoryB',_'superA',_'breadA') Integer
# 0 <= production_(7,_'factoryB',_'superA',_'breadB') Integer
# 0 <= production_(7,_'factoryB',_'superB',_'breadA') Integer
# 0 <= production_(7,_'factoryB',_'superB',_'breadB') Integer
# 0 <= production_(7,_'factoryB',_'superC',_'breadA') Integer
# 0 <= production_(7,_'factoryB',_'superC',_'breadB') Integer
# 0 <= production_(8,_'factoryA',_'superA',_'breadA') Integer
# 0 <= production_(8,_'factoryA',_'superA',_'breadB') Integer
# 0 <= production_(8,_'factoryA',_'superB',_'breadA') Integer
# 0 <= production_(8,_'factoryA',_'superB',_'breadB') Integer
# 0 <= production_(8,_'factoryA',_'superC',_'breadA') Integer
# 0 <= production_(8,_'factoryA',_'superC',_'breadB') Integer
# 0 <= production_(8,_'factoryB',_'superA',_'breadA') Integer
# 0 <= production_(8,_'factoryB',_'superA',_'breadB') Integer
# 0 <= production_(8,_'factoryB',_'superB',_'breadA') Integer
# 0 <= production_(8,_'factoryB',_'superB',_'breadB') Integer
# 0 <= production_(8,_'factoryB',_'superC',_'breadA') Integer
# 0 <= production_(8,_'factoryB',_'superC',_'breadB') Integer
# 0 <= production_(9,_'factoryA',_'superA',_'breadA') Integer
# 0 <= production_(9,_'factoryA',_'superA',_'breadB') Integer
# 0 <= production_(9,_'factoryA',_'superB',_'breadA') Integer
# 0 <= production_(9,_'factoryA',_'superB',_'breadB') Integer
# 0 <= production_(9,_'factoryA',_'superC',_'breadA') Integer
# 0 <= production_(9,_'factoryA',_'superC',_'breadB') Integer
# 0 <= production_(9,_'factoryB',_'superA',_'breadA') Integer
# 0 <= production_(9,_'factoryB',_'superA',_'breadB') Integer
# 0 <= production_(9,_'factoryB',_'superB',_'breadA') Integer
# 0 <= production_(9,_'factoryB',_'superB',_'breadB') Integer
# 0 <= production_(9,_'factoryB',_'superC',_'breadA') Integer
# 0 <= production_(9,_'factoryB',_'superC',_'breadB') Integer

# %% [markdown]
# ### Step 5: Solve linear equation.

# %%
model.solve()
pulp.LpStatus[model.status]
# Out:
# 'Optimal'

# %%
total_cost = pulp.value(model.objective)

print(f'The optimized cost is {round(total_cost, 2)}.')
# Out:
# The optimized cost is 5757150.0.

# %%
for variable in production:
    var_value = production[variable].varValue
    print(production[variable], var_value)
# Out:
# production_(1,_'factoryA',_'superA',_'breadA') 700.0
# production_(1,_'factoryA',_'superA',_'breadB') 620.0
# production_(1,_'factoryA',_'superB',_'breadA') 710.0
# production_(1,_'factoryA',_'superB',_'breadB') 770.0
# production_(1,_'factoryA',_'superC',_'breadA') 770.0
# production_(1,_'factoryA',_'superC',_'breadB') 680.0
# production_(2,_'factoryA',_'superA',_'breadA') 780.0
# production_(2,_'factoryA',_'superA',_'breadB') 700.0
# production_(2,_'factoryA',_'superB',_'breadA') 730.0
# production_(2,_'factoryA',_'superB',_'breadB') 670.0
# production_(2,_'factoryA',_'superC',_'breadA') 760.0
# production_(2,_'factoryA',_'superC',_'breadB') 650.0
# production_(3,_'factoryA',_'superA',_'breadA') 730.0
# production_(3,_'factoryA',_'superA',_'breadB') 600.0
# production_(3,_'factoryA',_'superB',_'breadA') 0.0
# production_(3,_'factoryA',_'superB',_'breadB') 0.0
# production_(3,_'factoryA',_'superC',_'breadA') 750.0
# production_(3,_'factoryA',_'superC',_'breadB') 670.0
# production_(4,_'factoryA',_'superA',_'breadA') 710.0
# production_(4,_'factoryA',_'superA',_'breadB') 680.0
# production_(4,_'factoryA',_'superB',_'breadA') 0.0
# production_(4,_'factoryA',_'superB',_'breadB') 0.0
# production_(4,_'factoryA',_'superC',_'breadA') 680.0
# production_(4,_'factoryA',_'superC',_'breadB') 680.0
# production_(5,_'factoryA',_'superA',_'breadA') 670.0
# production_(5,_'factoryA',_'superA',_'breadB') 790.0
# production_(5,_'factoryA',_'superB',_'breadA') 0.0
# production_(5,_'factoryA',_'superB',_'breadB') 0.0
# production_(5,_'factoryA',_'superC',_'breadA') 0.0
# production_(5,_'factoryA',_'superC',_'breadB') 0.0
# production_(6,_'factoryA',_'superA',_'breadA') 680.0
# production_(6,_'factoryA',_'superA',_'breadB') 660.0
# production_(6,_'factoryA',_'superB',_'breadA') 710.0
# production_(6,_'factoryA',_'superB',_'breadB') 700.0
# production_(6,_'factoryA',_'superC',_'breadA') 690.0
# production_(6,_'factoryA',_'superC',_'breadB') 690.0
# production_(7,_'factoryA',_'superA',_'breadA') 0.0
# production_(7,_'factoryA',_'superA',_'breadB') 0.0
# production_(7,_'factoryA',_'superB',_'breadA') 0.0
# production_(7,_'factoryA',_'superB',_'breadB') 0.0
# production_(7,_'factoryA',_'superC',_'breadA') 0.0
# production_(7,_'factoryA',_'superC',_'breadB') 0.0
# production_(8,_'factoryA',_'superA',_'breadA') 750.0
# production_(8,_'factoryA',_'superA',_'breadB') 710.0
# production_(8,_'factoryA',_'superB',_'breadA') 0.0
# production_(8,_'factoryA',_'superB',_'breadB') 0.0
# production_(8,_'factoryA',_'superC',_'breadA') 0.0
# production_(8,_'factoryA',_'superC',_'breadB') 0.0
# production_(9,_'factoryA',_'superA',_'breadA') 710.0
# production_(9,_'factoryA',_'superA',_'breadB') 700.0
# production_(9,_'factoryA',_'superB',_'breadA') 0.0
# production_(9,_'factoryA',_'superB',_'breadB') 0.0
# production_(9,_'factoryA',_'superC',_'breadA') 710.0
# production_(9,_'factoryA',_'superC',_'breadB') 730.0
# production_(10,_'factoryA',_'superA',_'breadA') 660.0
# production_(10,_'factoryA',_'superA',_'breadB') 690.0
# production_(10,_'factoryA',_'superB',_'breadA') 0.0
# production_(10,_'factoryA',_'superB',_'breadB') 0.0
# production_(10,_'factoryA',_'superC',_'breadA') 700.0
# production_(10,_'factoryA',_'superC',_'breadB') 700.0
# production_(11,_'factoryA',_'superA',_'breadA') 770.0
# production_(11,_'factoryA',_'superA',_'breadB') 690.0
# production_(11,_'factoryA',_'superB',_'breadA') 750.0
# production_(11,_'factoryA',_'superB',_'breadB') 680.0
# production_(11,_'factoryA',_'superC',_'breadA') 700.0
# production_(11,_'factoryA',_'superC',_'breadB') 680.0
# production_(12,_'factoryA',_'superA',_'breadA') 680.0
# production_(12,_'factoryA',_'superA',_'breadB') 760.0
# production_(12,_'factoryA',_'superB',_'breadA') 770.0
# production_(12,_'factoryA',_'superB',_'breadB') 690.0
# production_(12,_'factoryA',_'superC',_'breadA') 690.0
# production_(12,_'factoryA',_'superC',_'breadB') 690.0
# production_(3,_'factoryB',_'superA',_'breadA') 0.0
# production_(3,_'factoryB',_'superA',_'breadB') 0.0
# production_(3,_'factoryB',_'superB',_'breadA') 680.0
# production_(3,_'factoryB',_'superB',_'breadB') 650.0
# production_(3,_'factoryB',_'superC',_'breadA') 0.0
# production_(3,_'factoryB',_'superC',_'breadB') 0.0
# production_(4,_'factoryB',_'superA',_'breadA') 0.0
# production_(4,_'factoryB',_'superA',_'breadB') 0.0
# production_(4,_'factoryB',_'superB',_'breadA') 680.0
# production_(4,_'factoryB',_'superB',_'breadB') 740.0
# production_(4,_'factoryB',_'superC',_'breadA') 0.0
# production_(4,_'factoryB',_'superC',_'breadB') 0.0
# production_(5,_'factoryB',_'superA',_'breadA') 0.0
# production_(5,_'factoryB',_'superA',_'breadB') 0.0
# production_(5,_'factoryB',_'superB',_'breadA') 700.0
# production_(5,_'factoryB',_'superB',_'breadB') 680.0
# production_(5,_'factoryB',_'superC',_'breadA') 680.0
# production_(5,_'factoryB',_'superC',_'breadB') 690.0
# production_(6,_'factoryB',_'superA',_'breadA') 0.0
# production_(6,_'factoryB',_'superA',_'breadB') 0.0
# production_(6,_'factoryB',_'superB',_'breadA') 0.0
# production_(6,_'factoryB',_'superB',_'breadB') 0.0
# production_(6,_'factoryB',_'superC',_'breadA') 0.0
# production_(6,_'factoryB',_'superC',_'breadB') 0.0
# production_(7,_'factoryB',_'superA',_'breadA') 690.0
# production_(7,_'factoryB',_'superA',_'breadB') 780.0
# production_(7,_'factoryB',_'superB',_'breadA') 700.0
# production_(7,_'factoryB',_'superB',_'breadB') 790.0
# production_(7,_'factoryB',_'superC',_'breadA') 660.0
# production_(7,_'factoryB',_'superC',_'breadB') 710.0
# production_(8,_'factoryB',_'superA',_'breadA') 0.0
# production_(8,_'factoryB',_'superA',_'breadB') 0.0
# production_(8,_'factoryB',_'superB',_'breadA') 790.0
# production_(8,_'factoryB',_'superB',_'breadB') 780.0
# production_(8,_'factoryB',_'superC',_'breadA') 700.0
# production_(8,_'factoryB',_'superC',_'breadB') 700.0
# production_(9,_'factoryB',_'superA',_'breadA') 0.0
# production_(9,_'factoryB',_'superA',_'breadB') 0.0
# production_(9,_'factoryB',_'superB',_'breadA') 780.0
# production_(9,_'factoryB',_'superB',_'breadB') 710.0
# production_(9,_'factoryB',_'superC',_'breadA') 0.0
# production_(9,_'factoryB',_'superC',_'breadB') 0.0
# production_(10,_'factoryB',_'superA',_'breadA') 0.0
# production_(10,_'factoryB',_'superA',_'breadB') 0.0
# production_(10,_'factoryB',_'superB',_'breadA') 660.0
# production_(10,_'factoryB',_'superB',_'breadB') 710.0
# production_(10,_'factoryB',_'superC',_'breadA') 0.0
# production_(10,_'factoryB',_'superC',_'breadB') 0.0
# production_(11,_'factoryB',_'superA',_'breadA') 0.0
# production_(11,_'factoryB',_'superA',_'breadB') 0.0
# production_(11,_'factoryB',_'superB',_'breadA') 0.0
# production_(11,_'factoryB',_'superB',_'breadB') 0.0
# production_(11,_'factoryB',_'superC',_'breadA') 0.0
# production_(11,_'factoryB',_'superC',_'breadB') 0.0
# production_(12,_'factoryB',_'superA',_'breadA') 0.0
# production_(12,_'factoryB',_'superA',_'breadB') 0.0
# production_(12,_'factoryB',_'superB',_'breadA') 0.0
# production_(12,_'factoryB',_'superB',_'breadB') 0.0
# production_(12,_'factoryB',_'superC',_'breadA') 0.0
# production_(12,_'factoryB',_'superC',_'breadB') 0.0
# production_(1,_'factoryB',_'superA',_'breadA') 0.0
# production_(1,_'factoryB',_'superA',_'breadB') 0.0
# production_(1,_'factoryB',_'superB',_'breadA') 0.0
# production_(1,_'factoryB',_'superB',_'breadB') 0.0
# production_(1,_'factoryB',_'superC',_'breadA') 0.0
# production_(1,_'factoryB',_'superC',_'breadB') 0.0
# production_(2,_'factoryB',_'superA',_'breadA') 0.0
# production_(2,_'factoryB',_'superA',_'breadB') 0.0
# production_(2,_'factoryB',_'superB',_'breadA') 0.0
# production_(2,_'factoryB',_'superB',_'breadB') 0.0
# production_(2,_'factoryB',_'superC',_'breadA') 0.0
# production_(2,_'factoryB',_'superC',_'breadB') 0.0

# %%
for variable in logistic_status:
    var_value = logistic_status[variable].varValue
    print(logistic_status[variable], var_value)
# Out:
# logistic_status_(1,_'factoryA',_'superA') 1.0
# logistic_status_(1,_'factoryA',_'superB') 1.0
# logistic_status_(1,_'factoryA',_'superC') 1.0
# logistic_status_(1,_'factoryB',_'superA') 0.0
# logistic_status_(1,_'factoryB',_'superB') 0.0
# logistic_status_(1,_'factoryB',_'superC') 0.0
# logistic_status_(2,_'factoryA',_'superA') 1.0
# logistic_status_(2,_'factoryA',_'superB') 1.0
# logistic_status_(2,_'factoryA',_'superC') 1.0
# logistic_status_(2,_'factoryB',_'superA') 0.0
# logistic_status_(2,_'factoryB',_'superB') 0.0
# logistic_status_(2,_'factoryB',_'superC') 0.0
# logistic_status_(3,_'factoryA',_'superA') 1.0
# logistic_status_(3,_'factoryA',_'superB') 0.0
# logistic_status_(3,_'factoryA',_'superC') 1.0
# logistic_status_(3,_'factoryB',_'superA') 0.0
# logistic_status_(3,_'factoryB',_'superB') 1.0
# logistic_status_(3,_'factoryB',_'superC') 0.0
# logistic_status_(4,_'factoryA',_'superA') 1.0
# logistic_status_(4,_'factoryA',_'superB') 0.0
# logistic_status_(4,_'factoryA',_'superC') 1.0
# logistic_status_(4,_'factoryB',_'superA') 0.0
# logistic_status_(4,_'factoryB',_'superB') 1.0
# logistic_status_(4,_'factoryB',_'superC') 0.0
# logistic_status_(5,_'factoryA',_'superA') 1.0
# logistic_status_(5,_'factoryA',_'superB') 0.0
# logistic_status_(5,_'factoryA',_'superC') 0.0
# logistic_status_(5,_'factoryB',_'superA') 0.0
# logistic_status_(5,_'factoryB',_'superB') 1.0
# logistic_status_(5,_'factoryB',_'superC') 1.0
# logistic_status_(6,_'factoryA',_'superA') 1.0
# logistic_status_(6,_'factoryA',_'superB') 1.0
# logistic_status_(6,_'factoryA',_'superC') 1.0
# logistic_status_(6,_'factoryB',_'superA') 0.0
# logistic_status_(6,_'factoryB',_'superB') 0.0
# logistic_status_(6,_'factoryB',_'superC') 0.0
# logistic_status_(7,_'factoryA',_'superA') 0.0
# logistic_status_(7,_'factoryA',_'superB') 0.0
# logistic_status_(7,_'factoryA',_'superC') 0.0
# logistic_status_(7,_'factoryB',_'superA') 1.0
# logistic_status_(7,_'factoryB',_'superB') 1.0
# logistic_status_(7,_'factoryB',_'superC') 1.0
# logistic_status_(8,_'factoryA',_'superA') 1.0
# logistic_status_(8,_'factoryA',_'superB') 0.0
# logistic_status_(8,_'factoryA',_'superC') 0.0
# logistic_status_(8,_'factoryB',_'superA') 0.0
# logistic_status_(8,_'factoryB',_'superB') 1.0
# logistic_status_(8,_'factoryB',_'superC') 1.0
# logistic_status_(9,_'factoryA',_'superA') 1.0
# logistic_status_(9,_'factoryA',_'superB') 0.0
# logistic_status_(9,_'factoryA',_'superC') 1.0
# logistic_status_(9,_'factoryB',_'superA') 0.0
# logistic_status_(9,_'factoryB',_'superB') 1.0
# logistic_status_(9,_'factoryB',_'superC') 0.0
# logistic_status_(10,_'factoryA',_'superA') 1.0
# logistic_status_(10,_'factoryA',_'superB') 0.0
# logistic_status_(10,_'factoryA',_'superC') 1.0
# logistic_status_(10,_'factoryB',_'superA') 0.0
# logistic_status_(10,_'factoryB',_'superB') 1.0
# logistic_status_(10,_'factoryB',_'superC') 0.0
# logistic_status_(11,_'factoryA',_'superA') 1.0
# logistic_status_(11,_'factoryA',_'superB') 1.0
# logistic_status_(11,_'factoryA',_'superC') 1.0
# logistic_status_(11,_'factoryB',_'superA') 0.0
# logistic_status_(11,_'factoryB',_'superB') 0.0
# logistic_status_(11,_'factoryB',_'superC') 0.0
# logistic_status_(12,_'factoryA',_'superA') 1.0
# logistic_status_(12,_'factoryA',_'superB') 1.0
# logistic_status_(12,_'factoryA',_'superC') 1.0
# logistic_status_(12,_'factoryB',_'superA') 0.0
# logistic_status_(12,_'factoryB',_'superB') 0.0
# logistic_status_(12,_'factoryB',_'superC') 0.0

# %%
for variable in factory_status:
    var_value = factory_status[variable].varValue
    print(factory_status[variable], var_value)
# Out:
# factory_status_(1,_'factoryA') 1.0
# factory_status_(2,_'factoryA') 1.0
# factory_status_(3,_'factoryA') 1.0
# factory_status_(4,_'factoryA') 1.0
# factory_status_(5,_'factoryA') 1.0
# factory_status_(6,_'factoryA') 1.0
# factory_status_(7,_'factoryA') 1.0
# factory_status_(8,_'factoryA') 1.0
# factory_status_(9,_'factoryA') 1.0
# factory_status_(10,_'factoryA') 1.0
# factory_status_(11,_'factoryA') 1.0
# factory_status_(12,_'factoryA') 1.0
# factory_status_(3,_'factoryB') 0.0
# factory_status_(4,_'factoryB') 0.0
# factory_status_(5,_'factoryB') 0.0
# factory_status_(6,_'factoryB') 0.0
# factory_status_(7,_'factoryB') 0.0
# factory_status_(8,_'factoryB') 0.0
# factory_status_(9,_'factoryB') 0.0
# factory_status_(10,_'factoryB') 0.0
# factory_status_(11,_'factoryB') 0.0
# factory_status_(12,_'factoryB') 0.0
# factory_status_(1,_'factoryB') 0.0
# factory_status_(2,_'factoryB') 0.0

# %% [markdown]
# ## Archieve

# %%
df_demand_superA = pd.read_csv('dataset/demand_superA.csv')
df_demand_superB = pd.read_csv('dataset/demand_superB.csv')
df_demand_superC = pd.read_csv('dataset/demand_superC.csv')

df_demand_superA.rename(columns={'breadA':'superA_breadA', 'breadB':'superA_breadB'}, 
                        inplace=True)
df_demand_superB.rename(columns={'breadA':'superB_breadA', 'breadB':'superB_breadB'}, 
                        inplace=True)
df_demand_superC.rename(columns={'breadA':'superC_breadA', 'breadB':'superC_breadB'}, 
                        inplace=True)

df_demand = pd.merge(df_demand_superA, df_demand_superB, on='month')
df_demand = pd.merge(df_demand, df_demand_superC, on='month')

df_demand.head()

# %%
df_cost_factoryA = pd.read_csv('dataset/cost_factoryA.csv')
df_cost_factoryB = pd.read_csv('dataset/cost_factoryB.csv')

df_cost_factoryA.head()

df_cost_factoryA.rename(columns={'fixed_cost':'factoryA_fixed_cost',
                                 'breadA_production_cost':'factoryA_breadA', 
                                 'breadB_production_cost':'factoryA_breadB'}, 
                        inplace=True)
df_cost_factoryB.rename(columns={'fixed_cost':'factoryB_fixed_cost',
                                 'breadA_production_cost':'factoryB_breadA', 
                                 'breadB_production_cost':'factoryB_breadB'}, 
                        inplace=True)

df_cost = pd.merge(df_cost_factoryA, df_cost_factoryB, on='month')

df_cost.head()
